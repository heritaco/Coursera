# %% [markdown]
# Exacto, lo tienes casi: una **martingala** es un proceso estocástico que modela un “juego justo”: el valor esperado futuro, dado todo lo que sabes hoy, es **exactamente igual** al valor presente.
#
# ---
#
# ### 1. El símbolo $P$
#
# Ese superíndice $E^P$ significa que la **esperanza se toma bajo la probabilidad $P$**.
# En teoría de probabilidad formal siempre se trabaja dentro de un **espacio de probabilidad** $(\Omega,\mathcal{F},P)$. Entonces:
#
# * $E^P[\cdot]$ = esperanza respecto a la medida de probabilidad $P$.
# * A veces se omite y se escribe solo $E[\cdot]$ si el contexto es claro.
#
# ---
#
# ### 2. Definición intuitiva
#
# Un proceso $\{X_n\}$ es martingala si:
#
# 1. Los valores no son “explosivos” ($E[|X_n|]<\infty$).
# 2. El valor esperado futuro, condicionado a toda la información actual $\mathcal{F}_n$, es igual al valor presente:
#
#    $$
#    E[X_{n+m} \mid \mathcal{F}_n] = X_n.
#    $$
#
# ---
#
# ### 3. Intuición de $\mathcal{F}_n$ (la “filtración”)
#
# $\mathcal{F}_n$ es **toda la información disponible hasta el tiempo $n$**.
# Ejemplo: si estás apostando en un casino, $\mathcal{F}_n$ incluye el historial de todas las apuestas y resultados hasta ese momento.
#
# ---
#
# ### 4. Interpretación
#
# * Martingala: **juego justo**, no hay ventaja esperada.
# * Submartingala: en promedio, tiende a subir (juego sesgado a tu favor).
# * Supermartingala: en promedio, tiende a bajar (juego sesgado en tu contra).
#
# ---
#
# 👉 Entonces tu intuición es correcta:
#
# > “una martingala es un proceso en el tiempo que siempre mantiene el mismo valor esperado, dado el pasado”
#
# Lo único que faltaba es entender que la **P** solo recuerda que esa expectativa depende de la medida de probabilidad del modelo.
#
# ---
#
# ¿Quieres que te muestre un **ejemplo concreto** con una caminata aleatoria simple y verificar con cálculo que es una martingala?

# %% [markdown]
# Perfecto, veamos un ejemplo clásico y muy simple: la **caminata aleatoria simétrica**.
#
# ---
#
# ## 1. Definición
#
# Sea $\{X_n\}_{n\ge0}$ un proceso definido por
#
# $$
# X_0 = 0, \qquad
# X_{n} = X_{n-1} + Z_n,
# $$
#
# donde los $Z_n$ son variables independientes con
#
# $$
# P(Z_n = +1) = \tfrac12, \quad P(Z_n=-1)=\tfrac12.
# $$
#
# ---
#
# ## 2. Verificación de martingala
#
# * **Condición 1:** $E[|X_n|] < \infty$.
#   Sí, porque $|X_n|\le n$ y $E[|X_n|]\le n < \infty$.
#
# * **Condición 2:**
#   Queremos probar
#
#   $$
#   E[X_{n+1}\mid \mathcal{F}_n] = X_n.
#   $$
#
#   Como
#
#   $$
#   X_{n+1}=X_n+Z_{n+1},
#   $$
#
#   y dado $\mathcal{F}_n$ ya conocemos $X_n$, entonces:
#
#   $$
#   E[X_{n+1}\mid \mathcal{F}_n] = X_n + E[Z_{n+1}\mid \mathcal{F}_n].
#   $$
#
#   Pero $Z_{n+1}$ es independiente y su esperanza es 0,
#   así que
#
#   $$
#   E[X_{n+1}\mid \mathcal{F}_n] = X_n.
#   $$
#
# ✅ Cumple la definición: $\{X_n\}$ es una **martingala**.
#
# ---
#
# ## 3. Intuición
#
# Es como apostar cara o cruz, ganando +1 o perdiendo −1 cada vez.
#
# * Tu **valor esperado futuro**, sabiendo tu historial hasta ahora, es simplemente lo que llevas acumulado hoy.
# * No importa lo que haya pasado antes, el “juego” sigue siendo justo.
#
# ---
#
# ## 4. Variaciones
#
# * Si en lugar de $P(Z=+1)=P(Z=-1)=0.5$, usas $P(Z=+1)=p \neq 0.5$, entonces ya **no** es martingala. Se vuelve **submartingala** si $p>0.5$ o **supermartingala** si $p<0.5$.
#
# ---
#
# ¿Quieres que te arme un **código en Python** para simular varias trayectorias de esta caminata aleatoria y mostrar cómo en promedio se cumple la propiedad de martingala?

# %% [markdown]
# Sí. Para la caminata aleatoria simétrica $X_n=\sum_{i=1}^n Z_i$ con $Z_i\in\{+1,-1\}$, $P=1/2$, i.i.d.:
#
# ---
#
# ## Momentos, mgf y cf
#
# * Media:
#
#   $$
#   \mathbb{E}[X_n]=\sum_{i=1}^n\mathbb{E}[Z_i]=0.
#   $$
#
# * Varianza:
#
#   $$
#   \mathrm{Var}(X_n)=\sum_{i=1}^n\mathrm{Var}(Z_i)=n.
#   $$
#
# * Tercer momento central:
#
#   $$
#   \mathbb{E}[(X_n-\mathbb{E}X_n)^3]=0 \quad(\text{simetría}).
#   $$
#
# * Cuarto momento:
#
#   $$
#   \mathbb{E}[X_n^{4}]
#   =\sum_i \mathbb{E}[Z_i^4]+6\!\!\sum_{i<j}\!\!\mathbb{E}[Z_i^2]\mathbb{E}[Z_j^2]
#   =n+3n(n-1)=3n^2-2n.
#   $$
#
# * Exceso de curtosis:
#
#   $$
#   \gamma_2=\frac{\mathbb{E}[X_n^{4}]}{\mathrm{Var}(X_n)^2}-3
#   =\frac{3n^2-2n}{n^2}-3=-\frac{2}{n}.
#   $$
#
#   Platocúrtica y $\gamma_2\to 0$ al crecer $n$ (se acerca a normal).
#
# * MGF:
#
#   $$
#   M_{X_n}(t)=\big(\mathbb{E}[e^{tZ_1}]\big)^n=(\cosh t)^n.
#   $$
#
# * Función característica:
#
#   $$
#   \varphi_{X_n}(t)=\big(\mathbb{E}[e^{itZ_1}]\big)^n=(\cos t)^n.
#   $$
#
# * Generatriz cumulante:
#
#   $$
#   K_{X_n}(t)=\log M_{X_n}(t)=n\log\cosh t.
#   $$
#
#   Cúmulos: $\kappa_1=0,\ \kappa_2=n,\ \kappa_3=0,\ \kappa_4=-2n$ (los impares $=0$ por simetría).
#
# ---
#
# ## Distribución exacta
#
# $$
# P(X_n=k)=\binom{n}{(n+k)/2}2^{-n},\quad k\equiv n\pmod 2,\ |k|\le n.
# $$
#
# ---
#
# ## Interpretación
#
# * **Martingala:** $\mathbb{E}[X_{n+1}\mid\mathcal{F}_n]=X_n$. Juego justo: la mejor predicción del futuro es el valor actual.
# * **Escala del riesgo:** la desviación típica crece como $\sqrt{n}$. Fluctuaciones $\sim O(\sqrt{n})$.
# * **Simetría:** asimetría $=0$. No hay sesgo direccional.
# * **Curtosis:** $\gamma_2=-2/n$. Menos colas que la normal para $n$ finito; converge a normal por CLT al estandarizar $X_n/\sqrt{n}\Rightarrow \mathcal N(0,1)$.
# * **Cumulantes aditivos:** muestran independencia; todos los impares 0, los pares escalan linealmente con $n$.

# %% [markdown]
# Muy buenas preguntas — vamos a desmenuzarlo paso a paso para que veas exactamente de dónde salen esos valores para la caminata aleatoria simétrica $X_n = \sum_{i=1}^n Z_i$, con $Z_i \in \{-1, +1\}$ con probabilidad $1/2$ cada uno.
#
# ---
#
# ## 1. Valor esperado de $Z$
#
# Como $Z$ solo toma dos valores:
#
# $$
# \mathbb{E}[Z] = (+1)\cdot \tfrac{1}{2} + (-1)\cdot \tfrac{1}{2} = 0.
# $$
#
# **Interpretación:** el paso está centrado en cero: no hay sesgo hacia la izquierda ni la derecha.
# Por linealidad,
#
# $$
# \mathbb{E}[X_n] = \sum_{i=1}^n \mathbb{E}[Z_i] = 0.
# $$
#
# ---
#
# ## 2. Varianza de $X_n$
#
# * Para una sola variable:
#
#   $$
#   \mathrm{Var}(Z) = \mathbb{E}[Z^2] - (\mathbb{E}[Z])^2 = 1 - 0 = 1,
#   $$
#
#   porque $Z^2 = 1$ siempre.
#
# * Para la suma: los $Z_i$ son i.i.d., entonces
#
#   $$
#   \mathrm{Var}(X_n) = \mathrm{Var}\Big(\sum_{i=1}^n Z_i\Big) = \sum_{i=1}^n \mathrm{Var}(Z_i) = n\cdot 1 = n.
#   $$
#
# **Interpretación:** la dispersión crece linealmente en el tiempo. La desviación típica $\sqrt{n}$ refleja el famoso “random walk scaling”.
#
# ---
#
# ## 3. Tercer momento de $X_n$
#
# * Como cada $Z_i$ es **simétrico respecto a 0**,
#
#   $$
#   \mathbb{E}[Z_i^3] = (+1)^3 \cdot \tfrac{1}{2} + (-1)^3 \cdot \tfrac{1}{2} = 0.
#   $$
# * Más aún, cualquier combinación con número impar de factores $Z_i$ tendrá esperanza 0 (porque las distribuciones simétricas “matan” las potencias impares).
# * Por eso,
#
#   $$
#   \mathbb{E}[X_n^3] = 0.
#   $$
#
# **Interpretación:** no hay asimetría en la caminata: la distribución es perfectamente simétrica alrededor de 0.
#
# ---
#
# ## 4. Cuarto momento de $X_n$
#
# Queremos
#
# $$
# \mathbb{E}[X_n^4] = \mathbb{E}\Big[\Big(\sum_{i=1}^n Z_i\Big)^4\Big].
# $$
#
# Expandiendo con multinomio:
#
# $$
# X_n^4 = \sum_i Z_i^4 + 6\sum_{i<j} Z_i^2 Z_j^2 + \text{(términos con potencias impares)}.
# $$
#
# * Los términos con potencias impares tienen esperanza 0 (por simetría).
#
# * Como $Z_i^2=1$, se simplifica:
#
#   $$
#   \mathbb{E}[X_n^4] = n \cdot \mathbb{E}[Z_1^4] + 6 \binom{n}{2}\cdot \mathbb{E}[Z_1^2]\mathbb{E}[Z_2^2].
#   $$
#
# * Como $\mathbb{E}[Z^4]=1$ y $\mathbb{E}[Z^2]=1$,
#
#   $$
#   \mathbb{E}[X_n^4] = n \cdot 1 + 6 \cdot \frac{n(n-1)}{2}\cdot 1 = n + 3n(n-1).
#   $$
#
# $$
# \boxed{\mathbb{E}[X_n^4] = 3n^2 - 2n.}
# $$
#
# ---
#
# ## 5. ¿Y de dónde sale el “$-2n$”?
#
# Eso no es el **cuarto momento**, sino el **cuarto cúmulo** $\kappa_4$.
#
# * Los cúmulos se obtienen del logaritmo de la MGF.
# * Para nuestra caminata:
#
#   * $\kappa_1 = 0$ (media),
#   * $\kappa_2 = n$ (varianza),
#   * $\kappa_3 = 0$ (simetría),
#   * $\kappa_4 = -2n$.
#
# **Interpretación:** $\kappa_4$ mide el exceso de curtosis. Un valor negativo ($-2n$) indica que la distribución tiene colas más delgadas que la normal (“platocúrtica”).
#
# ---
#
# 👉 Resumen:
#
# * $E[Z]=0$ por simetría.
# * $\mathrm{Var}(X_n)=n$ porque las varianzas se suman.
# * El tercer momento es 0 por simetría.
# * El cuarto momento es $3n^2-2n$.
# * El “$-2n$” es en realidad el **cuarto cúmulo**, no el momento.
#
# ---
#
# ¿Quieres que te arme una tablita comparando **momentos vs cúmulos** hasta orden 4 para $X_n$ (con su interpretación en términos de media, varianza, asimetría y curtosis)?
