# %% [markdown]
# # Programming Assignment

# %% [markdown]
# ## Model validation on the Iris dataset

# %% [markdown]
# ### Instructions
#
# In this notebook, you will build, compile and fit a neural network model to the Iris dataset. You will also implement validation, regularisation and callbacks to improve your model.
#
# Some code cells are provided you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook
from numpy.random import seed
seed(8)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, model_selection
# %matplotlib inline

# If you would like to make further imports from tensorflow, add them here
# Out:
# 2025-11-26 20:44:46.582269: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 20:44:46.640841: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 20:44:47.961426: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# #### The Iris dataset
#
# In this assignment, you will use the [Iris dataset](https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html). It consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters. For a reference, see the following papers:
#
# - R. A. Fisher. "The use of multiple measurements in taxonomic problems". Annals of Eugenics. 7 (2): 179–188, 1936.
#
# Your goal is to construct a neural network that classifies each sample into the correct class, as well as applying validation and regularisation techniques.

# %% [markdown]
# #### Load and preprocess the data
#
# First read in the Iris dataset using `datasets.load_iris()`, and split the dataset into training and test sets.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def read_in_and_split_data(iris_data):
    """
    This function takes the Iris dataset as loaded by sklearn.datasets.load_iris(), and then
    splits so that the training set includes 90% of the full dataset, with the test set
    making up the remaining 10%.
    Your function should return a tuple (train_data, test_data, train_targets, test_targets)
    of appropriately split training and test data and targets.

    If you would like to import any further packages to aid you in this task, please do so in the
    Package Imports cell above.
    """
    
    train_data, test_data, train_targets, test_targets = model_selection.train_test_split(
        iris_data.data,
        iris_data.target,
        test_size=0.1,\
    )
    return (train_data, test_data, train_targets, test_targets)

# %%
# Run your function to generate the test and training data.

iris_data = datasets.load_iris()
train_data, test_data, train_targets, test_targets = read_in_and_split_data(iris_data)

# %% [markdown]
# We will now convert the training and test targets using a one hot encoder.

# %%
# Convert targets to a one-hot encoding

train_targets = tf.keras.utils.to_categorical(np.array(train_targets))
test_targets = tf.keras.utils.to_categorical(np.array(test_targets))

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# You can now construct a model to fit to the data. Using the Sequential API, build your model according to the following specifications:
#
# * The model should use the `input_shape` in the function argument to set the input size in the first layer.
# * The first layer should be a dense layer with 64 units.
# * The weights of the first layer should be initialised with the He uniform initializer.
# * The biases of the first layer should be all initially equal to one.
# * There should then be a further four dense layers, each with 128 units.
# * This should be followed with four dense layers, each with 64 units.
# * All of these Dense layers should use the ReLU activation function.
# * The output Dense layer should have 3 units and the softmax activation function.
#
# In total, the network should have 10 layers.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def get_model(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """

    model = tf.keras.Sequential()

    # 1) First Dense layer: 64 units, He uniform, bias = 1, uses input_shape
    model.add(
        tf.keras.layers.Dense(
            64,
            activation='relu',
            input_shape=input_shape,
            kernel_initializer='he_uniform',
            bias_initializer=tf.keras.initializers.Constant(1.0),
        )
    )

    # 2) Next four Dense layers: 128 units, ReLU
    for _ in range(4):
        model.add(tf.keras.layers.Dense(128, activation='relu'))

    # 3) Next four Dense layers: 64 units, ReLU
    for _ in range(4):
        model.add(tf.keras.layers.Dense(64, activation='relu'))

    # 4) Output Dense layer: 3 units, softmax
    model.add(tf.keras.layers.Dense(3, activation='softmax'))

    return model

# %%
# Run your function to get the model

model = get_model(train_data[0].shape)
# Out:
# /home/nvidia/miniforge3/envs/rapids-25.10-cuda12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764212734.141038  380926 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5561 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# #### Compile the model
#
# You should now compile the model using the `compile` method. Remember that you need to specify an optimizer, a loss function and a metric to judge the performance of your model.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def compile_model(model):
    """
    This function takes in the model returned from your get_model function, and compiles it with an optimiser,
    loss function and metric.
    Compile the model using the Adam optimiser (with learning rate set to 0.0001),
    the categorical crossentropy loss function and accuracy as the only metric.
    Your function doesn't need to return anything; the model will be compiled in-place.
    """

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    loss = 'categorical_crossentropy'
    metrics = ['accuracy']

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=metrics,
    )

# %%
# Run your function to compile the model

compile_model(model)

# %% [markdown]
# #### Fit the model to the training data
#
# Now you should train the model on the Iris dataset, using the model's `fit` method.
# * Run the training for a fixed number of epochs, given by the function's `epochs` argument.
# * Return the training history to be used for plotting the learning curves.
# * Set the batch size to 40.
# * Set the validation set to be 15% of the training set.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def train_model(model, train_data, train_targets, epochs):
    """
    This function should train the model for the given number of epochs on the
    train_data and train_targets.
    Your function should return the training history, as returned by model.fit.
    """
    history = model.fit(
        train_data,
        train_targets,
        validation_split = 0.15,
        epochs=epochs,
        verbose=2,
        batch_size=40
    )
    return history

# %%
# Run your function to train the model

history = train_model(model, train_data, train_targets, epochs=800)
# Out:
# 2025-11-26 21:08:45.982736: I external/local_xla/xla/service/service.cc:163] XLA service 0x7c0a000023c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-26 21:08:45.982779: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-11-26 21:08:46.053499: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-26 21:08:46.517825: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 2025-11-26 21:08:46.576207: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:46.576287: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:46.576310: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:46.576321: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:46.576391: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:46.576399: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:46.576409: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:46.576422: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:46.576452: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:46.576467: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:08:49.435115: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_418', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 21:08:49.983113: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_418', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-26 21:08:51.331760: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_439', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 21:08:51.617007: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 21:08:53.542300: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_446', 1112 bytes spill stores, 1112 bytes spill loads
#
# 2025-11-26 21:08:53.585643: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_696', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 21:08:53.969904: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 21:08:54.218209: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_702', 104 bytes spill stores, 104 bytes spill loads
#
# 2025-11-26 21:08:54.711324: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_411', 1120 bytes spill stores, 1120 bytes spill loads
#
# 2025-11-26 21:08:55.566204: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_702', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 21:08:56.147556: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-11-26 21:08:56.260107: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-11-26 21:08:57.480753: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-26 21:08:58.087109: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_696', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-26 21:08:58.656710: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 476 bytes spill stores, 476 bytes spill loads
#
# I0000 00:00:1764212942.147227  385496 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-26 21:09:02.594842: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:02.594913: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:02.594924: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:02.594932: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:02.594954: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:02.594961: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:02.594972: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:02.594979: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:02.595008: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:02.595025: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:06.267686: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_411', 1120 bytes spill stores, 1120 bytes spill loads
#
# 2025-11-26 21:09:06.579686: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-11-26 21:09:06.678269: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_418', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 21:09:07.734752: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_418', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-26 21:09:09.153879: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_446', 1112 bytes spill stores, 1112 bytes spill loads
#
# 2025-11-26 21:09:09.351373: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_439', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 21:09:09.360534: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-11-26 21:09:09.639213: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_702', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 21:09:13.084070: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 476 bytes spill stores, 476 bytes spill loads
#
# 2025-11-26 21:09:13.443269: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_696', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 21:09:13.685758: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_702', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-26 21:09:14.278951: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 21:09:14.298454: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-26 21:09:14.356309: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_696', 96 bytes spill stores, 96 bytes spill loads
#
# 2025-11-26 21:09:14.379533: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 21:09:17.804127: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:17.804206: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:09:20.114068: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_115', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 21:09:20.333289: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-26 21:09:20.507928: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 292 bytes spill stores, 292 bytes spill loads

# %% [markdown]
# #### Plot the learning curves
#
# We will now plot two graphs:
# * Epoch vs accuracy
# * Epoch vs loss

# %%
#Run this cell to plot the epoch vs accuracy graph

try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the epoch vs loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# Oh no! We have overfit our dataset. You should now try to now try to mitigate this overfitting.

# %% [markdown]
# #### Reducing overfitting in the model

# %% [markdown]
# You should now define a new regularised model.
# The specs for the regularised model are the same as our original model, with the addition of two dropout layers, weight decay, and a batch normalisation layer.
#
# In particular:
#
# * Add a dropout layer after the 3rd Dense layer
# * Then there should be two more Dense layers with 128 units before a batch normalisation layer
# * Following this, two more Dense layers with 64 units and then another Dropout layer
# * Two more Dense layers with 64 units and then the final 3-way softmax layer
# * Add weight decay (l2 kernel regularisation) in all Dense layers except the final softmax layer

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def get_regularised_model(input_shape, dropout_rate, weight_decay):
    """
    This function should build a regularised Sequential model according to the above specification.
    The dropout_rate argument in the function should be used to set the Dropout rate for all Dropout layers.
    L2 kernel regularisation (weight decay) should be added using the weight_decay argument to
    set the weight decay coefficient in all Dense layers that use L2 regularisation.
    Ensure the weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument input_shape.
    Your function should return the model.
    """

    model = tf.keras.Sequential()

    # L2 regulariser (weight decay) to reuse
    l2_reg = tf.keras.regularizers.l2(weight_decay)

    # 1) First Dense layer: 64 units, He uniform, bias = 1, with L2, uses input_shape
    model.add(
        tf.keras.layers.Dense(
            64,
            activation="relu",
            input_shape=input_shape,
            kernel_initializer="he_uniform",
            bias_initializer=tf.keras.initializers.Constant(1.0),
            kernel_regularizer=l2_reg,
        )
    )

    # 2) Next two Dense layers (2nd and 3rd Dense): 128 units, ReLU, with L2
    model.add(tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=l2_reg))
    model.add(tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=l2_reg))

    # Dropout after 3rd Dense layer
    model.add(tf.keras.layers.Dropout(dropout_rate))

    # 3) Two more Dense(128) layers before BatchNorm, with L2
    model.add(tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=l2_reg))
    model.add(tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=l2_reg))

    # Batch Normalisation layer
    model.add(tf.keras.layers.BatchNormalization())

    # 4) Two Dense(64) layers, with L2
    model.add(tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=l2_reg))
    model.add(tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=l2_reg))

    # Dropout after these two Dense(64) layers
    model.add(tf.keras.layers.Dropout(dropout_rate))

    # 5) Two more Dense(64) layers, with L2
    model.add(tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=l2_reg))
    model.add(tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=l2_reg))

    # 6) Final softmax output layer (no L2 here)
    model.add(tf.keras.layers.Dense(3, activation="softmax"))

    return model

# %% [markdown]
# #### Instantiate, compile and train the model

# %%
# Instantiate the model, using a dropout rate of 0.3 and weight decay coefficient of 0.001

reg_model = get_regularised_model(train_data[0].shape, 0.3, 0.001)
# Out:
# /home/nvidia/miniforge3/envs/rapids-25.10-cuda12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model

compile_model(reg_model)

# %%
# Train the model

reg_history = train_model(reg_model, train_data, train_targets, epochs=800)
# Out:
# Epoch 1/800
# 3/3 - 16s - 5s/step - accuracy: 0.9912 - loss: 0.5378 - val_accuracy: 0.9524 - val_loss: 0.8076
# Epoch 2/800
# 3/3 - 0s - 57ms/step - accuracy: 0.9912 - loss: 0.5389 - val_accuracy: 0.9048 - val_loss: 0.8397
# Epoch 3/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9737 - loss: 0.6040 - val_accuracy: 0.9048 - val_loss: 0.8817
# Epoch 4/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9737 - loss: 0.6146 - val_accuracy: 0.9048 - val_loss: 0.8852
# Epoch 5/800
# 3/3 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.5133 - val_accuracy: 0.9048 - val_loss: 0.8621
# Epoch 6/800
# 3/3 - 0s - 52ms/step - accuracy: 1.0000 - loss: 0.5176 - val_accuracy: 0.9048 - val_loss: 0.8512
# Epoch 7/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9912 - loss: 0.5219 - val_accuracy: 0.9048 - val_loss: 0.8332
# Epoch 8/800
# 3/3 - 0s - 41ms/step - accuracy: 0.9825 - loss: 0.5279 - val_accuracy: 0.9048 - val_loss: 0.8091
# Epoch 9/800
# 3/3 - 0s - 39ms/step - accuracy: 0.9825 - loss: 0.5402 - val_accuracy: 0.9048 - val_loss: 0.7968
# Epoch 10/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.5142 - val_accuracy: 0.9048 - val_loss: 0.7953
# Epoch 11/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.5202 - val_accuracy: 0.9048 - val_loss: 0.7976
# Epoch 12/800
# 3/3 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.5162 - val_accuracy: 0.9048 - val_loss: 0.8036
# Epoch 13/800
# 3/3 - 0s - 39ms/step - accuracy: 0.9825 - loss: 0.5247 - val_accuracy: 0.9048 - val_loss: 0.8260
# Epoch 14/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.5148 - val_accuracy: 0.9048 - val_loss: 0.8348
# Epoch 15/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.5203 - val_accuracy: 0.9048 - val_loss: 0.8339
# Epoch 16/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.5074 - val_accuracy: 0.9048 - val_loss: 0.8228
# Epoch 17/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.5045 - val_accuracy: 0.9048 - val_loss: 0.8197
# Epoch 18/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.5027 - val_accuracy: 0.9048 - val_loss: 0.8177
# Epoch 19/800
# 3/3 - 0s - 41ms/step - accuracy: 0.9912 - loss: 0.5195 - val_accuracy: 0.9048 - val_loss: 0.8223
# Epoch 20/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.5200 - val_accuracy: 0.9048 - val_loss: 0.8271
# Epoch 21/800
# 3/3 - 0s - 45ms/step - accuracy: 0.9912 - loss: 0.5246 - val_accuracy: 0.9048 - val_loss: 0.8676
# Epoch 22/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.5209 - val_accuracy: 0.9048 - val_loss: 0.8674
# Epoch 23/800
# 3/3 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.5026 - val_accuracy: 0.9048 - val_loss: 0.8453
# Epoch 24/800
# 3/3 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.5026 - val_accuracy: 0.9048 - val_loss: 0.8225
# Epoch 25/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.5036 - val_accuracy: 0.9048 - val_loss: 0.8111
# Epoch 26/800
# 3/3 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.5040 - val_accuracy: 0.9048 - val_loss: 0.7969
# Epoch 27/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.4979 - val_accuracy: 0.9048 - val_loss: 0.7884
# Epoch 28/800
# 3/3 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.5065 - val_accuracy: 0.9048 - val_loss: 0.7789
# Epoch 29/800
# 3/3 - 1s - 194ms/step - accuracy: 0.9912 - loss: 0.5213 - val_accuracy: 0.9524 - val_loss: 0.7776
# Epoch 30/800
# 3/3 - 1s - 367ms/step - accuracy: 0.9912 - loss: 0.5066 - val_accuracy: 0.9048 - val_loss: 0.7946
# Epoch 31/800
# 3/3 - 1s - 316ms/step - accuracy: 1.0000 - loss: 0.4961 - val_accuracy: 0.9048 - val_loss: 0.8283
# Epoch 32/800
# 3/3 - 1s - 331ms/step - accuracy: 1.0000 - loss: 0.4964 - val_accuracy: 0.9048 - val_loss: 0.8478
# Epoch 33/800
# 3/3 - 1s - 400ms/step - accuracy: 1.0000 - loss: 0.4973 - val_accuracy: 0.9048 - val_loss: 0.8688
# Epoch 34/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9825 - loss: 0.5210 - val_accuracy: 0.9048 - val_loss: 0.8555
# Epoch 35/800
# 3/3 - 0s - 53ms/step - accuracy: 0.9912 - loss: 0.4988 - val_accuracy: 0.9048 - val_loss: 0.8130
# Epoch 36/800
# 3/3 - 0s - 57ms/step - accuracy: 1.0000 - loss: 0.4900 - val_accuracy: 0.9524 - val_loss: 0.8109
# Epoch 37/800
# 3/3 - 0s - 59ms/step - accuracy: 0.9912 - loss: 0.5010 - val_accuracy: 0.9524 - val_loss: 0.8142
# Epoch 38/800
# 3/3 - 0s - 60ms/step - accuracy: 0.9912 - loss: 0.5139 - val_accuracy: 0.9524 - val_loss: 0.8115
# Epoch 39/800
# 3/3 - 0s - 64ms/step - accuracy: 0.9912 - loss: 0.5102 - val_accuracy: 0.9048 - val_loss: 0.8902
# Epoch 40/800
# 3/3 - 0s - 81ms/step - accuracy: 0.9912 - loss: 0.5012 - val_accuracy: 0.9048 - val_loss: 0.9187
# Epoch 41/800
# 3/3 - 0s - 84ms/step - accuracy: 0.9912 - loss: 0.5071 - val_accuracy: 0.9048 - val_loss: 0.8843
# Epoch 42/800
# 3/3 - 0s - 92ms/step - accuracy: 1.0000 - loss: 0.4878 - val_accuracy: 0.9048 - val_loss: 0.8522
# Epoch 43/800
# 3/3 - 0s - 100ms/step - accuracy: 1.0000 - loss: 0.4854 - val_accuracy: 0.9048 - val_loss: 0.8339
# Epoch 44/800
# 3/3 - 0s - 122ms/step - accuracy: 1.0000 - loss: 0.4858 - val_accuracy: 0.9524 - val_loss: 0.8310
# Epoch 45/800
# 3/3 - 0s - 101ms/step - accuracy: 1.0000 - loss: 0.4864 - val_accuracy: 0.9524 - val_loss: 0.8340
# Epoch 46/800
# 3/3 - 0s - 108ms/step - accuracy: 0.9912 - loss: 0.5299 - val_accuracy: 0.9524 - val_loss: 0.8308
# Epoch 47/800
# 3/3 - 0s - 115ms/step - accuracy: 1.0000 - loss: 0.4828 - val_accuracy: 0.9524 - val_loss: 0.8344
# Epoch 48/800
# 3/3 - 0s - 108ms/step - accuracy: 0.9912 - loss: 0.5221 - val_accuracy: 0.9048 - val_loss: 0.8397
# Epoch 49/800
# 3/3 - 0s - 149ms/step - accuracy: 0.9912 - loss: 0.4944 - val_accuracy: 0.9048 - val_loss: 0.8628
# Epoch 50/800
# 3/3 - 0s - 163ms/step - accuracy: 0.9912 - loss: 0.4943 - val_accuracy: 0.9048 - val_loss: 0.8775
# Epoch 51/800
# 3/3 - 0s - 160ms/step - accuracy: 1.0000 - loss: 0.4840 - val_accuracy: 0.9048 - val_loss: 0.8220
# Epoch 52/800
# 3/3 - 0s - 125ms/step - accuracy: 0.9912 - loss: 0.5015 - val_accuracy: 0.9524 - val_loss: 0.7930
# Epoch 53/800
# 3/3 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.4810 - val_accuracy: 0.9524 - val_loss: 0.8090
# Epoch 54/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9825 - loss: 0.5240 - val_accuracy: 0.9524 - val_loss: 0.8028
# Epoch 55/800
# 3/3 - 0s - 33ms/step - accuracy: 0.
800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.4579 - val_accuracy: 0.9048 - val_loss: 0.8065
# Epoch 100/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.4654 - val_accuracy: 0.9048 - val_loss: 0.8142
# Epoch 101/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9825 - loss: 0.5174 - val_accuracy: 0.9048 - val_loss: 0.7582
# Epoch 102/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.4561 - val_accuracy: 0.9048 - val_loss: 0.7396
# Epoch 103/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.4832 - val_accuracy: 0.9048 - val_loss: 0.7342
# Epoch 104/800
# 3/3 - 0s - 30ms/step - accuracy: 0.9912 - loss: 0.4607 - val_accuracy: 0.9048 - val_loss: 0.7372
# Epoch 105/800
# 3/3 - 0s - 59ms/step - accuracy: 0.9912 - loss: 0.4758 - val_accuracy: 0.9048 - val_loss: 0.7452
# Epoch 106/800
# 3/3 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.4538 - val_accuracy: 0.9048 - val_loss: 0.7538
# Epoch 107/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.4652 - val_accuracy: 0.9048 - val_loss: 0.7520
# Epoch 108/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.4556 - val_accuracy: 0.9048 - val_loss: 0.7530
# Epoch 109/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.4539 - val_accuracy: 0.9048 - val_loss: 0.7536
# Epoch 110/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9737 - loss: 0.4895 - val_accuracy: 0.9048 - val_loss: 0.7462
# Epoch 111/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.4583 - val_accuracy: 0.9048 - val_loss: 0.7350
# Epoch 112/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.4554 - val_accuracy: 0.9524 - val_loss: 0.7307
# Epoch 113/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9912 - loss: 0.4868 - val_accuracy: 0.9524 - val_loss: 0.7333
# Epoch 114/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.4516 - val_accuracy: 0.9524 - val_loss: 0.7275
# Epoch 115/800
# 3/3 - 0s - 53ms/step - accuracy: 0.9912 - loss: 0.4651 - val_accuracy: 0.9048 - val_loss: 0.7303
# Epoch 116/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.4506 - val_accuracy: 0.9048 - val_loss: 0.7563
# Epoch 117/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.4494 - val_accuracy: 0.9048 - val_loss: 0.7763
# Epoch 118/800
# 3/3 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.4522 - val_accuracy: 0.9048 - val_loss: 0.7848
# Epoch 119/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.4766 - val_accuracy: 0.9048 - val_loss: 0.7664
# Epoch 120/800
# 3/3 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.4511 - val_accuracy: 0.9524 - val_loss: 0.7230
# Epoch 121/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.4496 - val_accuracy: 0.9524 - val_loss: 0.7220
# Epoch 122/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.4515 - val_accuracy: 0.9524 - val_loss: 0.7241
# Epoch 123/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.5188 - val_accuracy: 0.9524 - val_loss: 0.7245
# Epoch 124/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.4472 - val_accuracy: 0.9524 - val_loss: 0.7252
# Epoch 125/800
# 3/3 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.4504 - val_accuracy: 0.9524 - val_loss: 0.7252
# Epoch 126/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.4467 - val_accuracy: 0.9048 - val_loss: 0.7414
# Epoch 127/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.4497 - val_accuracy: 0.9048 - val_loss: 0.7577
# Epoch 128/800
# 3/3 - 0s - 61ms/step - accuracy: 1.0000 - loss: 0.4468 - val_accuracy: 0.9048 - val_loss: 0.7639
# Epoch 129/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.4446 - val_accuracy: 0.9048 - val_loss: 0.7640
# Epoch 130/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.4657 - val_accuracy: 0.9048 - val_loss: 0.8096
# Epoch 131/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.4471 - val_accuracy: 0.9048 - val_loss: 0.8305
# Epoch 132/800
# 3/3 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.4470 - val_accuracy: 0.9048 - val_loss: 0.8233
# Epoch 133/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.4458 - val_accuracy: 0.9048 - val_loss: 0.7667
# Epoch 134/800
# 3/3 - 0s - 28ms/step - accuracy: 0.9912 - loss: 0.4780 - val_accuracy: 0.9048 - val_loss: 0.7328
# Epoch 135/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.4423 - val_accuracy: 0.9048 - val_loss: 0.7125
# Epoch 136/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.4690 - val_accuracy: 0.9048 - val_loss: 0.7459
# Epoch 137/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.4408 - val_accuracy: 0.9048 - val_loss: 0.7666
# Epoch 138/800
# 3/3 - 0s - 54ms/step - accuracy: 0.9737 - loss: 0.4874 - val_accuracy: 0.9048 - val_loss: 0.7190
# Epoch 139/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.4430 - val_accuracy: 0.9048 - val_loss: 0.6998
# Epoch 140/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.4426 - val_accuracy: 0.9048 - val_loss: 0.6949
# Epoch 141/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.4393 - val_accuracy: 0.9524 - val_loss: 0.6921
# Epoch 142/800
# 3/3 - 0s - 37ms/step - accuracy: 0.9912 - loss: 0.4525 - val_accuracy: 0.9048 - val_loss: 0.6953
# Epoch 143/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.4396 - val_accuracy: 0.9048 - val_loss: 0.7049
# Epoch 144/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.4369 - val_accuracy: 0.9048 - val_loss: 0.7205
# Epoch 145/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.4415 - val_accuracy: 0.9048 - val_loss: 0.7482
# Epoch 146/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9825 - loss: 0.4538 - val_accuracy: 0.9048 - val_loss: 0.7405
# Epoch 147/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9912 - loss: 0.4611 - val_accuracy: 0.9048 - val_loss: 0.7224
# Epoch 148/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.4371 - val_accuracy: 0.9048 - val_loss: 0.7217
# Epoch 149/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9825 - loss: 0.4685 - val_accuracy: 0.9048 - val_loss: 0.7230
# Epoch 150/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.4410 - val_accuracy: 0.9524 - val_loss: 0.7086
# Epoch 151/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.4346 - val_accuracy: 0.9524 - val_loss: 0.7098
# Epoch 152/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.4382 - val_accuracy: 0.9524 - val_loss: 0.7138
# Epoch 153/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9912 - loss: 0.4607 - val_accuracy: 0.9524 - val_loss: 0.7124
# Epoch 154/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.4328 - val_accuracy: 0.9524 - val_loss: 0.7114
# Epoch 155/800
# 3/3 - 0s - 53ms/step - accuracy: 0.9912 - loss: 0.4451 - val_accuracy: 0.9524 - val_loss: 0.7118
# Epoch 156/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.4490 - val_accuracy: 0.9048 - val_loss: 0.7818
# Epoch 157/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.4357 - val_accuracy: 0.9048 - val_loss: 0.8299
# Epoch 158/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.4366 - val_accuracy: 0.9048 - val_loss: 0.8395
# Epoch 159/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.4344 - val_accuracy: 0.9048 - val_loss: 0.8431
# Epoch 160/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9912 - loss: 0.4424 - val_accuracy: 0.9048 - val_loss: 0.8379
# Epoch 161/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.4347 - val_accuracy: 0.9048 - val_loss: 0.8248
# Epoch 162/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9912 - loss: 0.4476 - val_accuracy: 0.9048 - val_loss: 0.8007
# Epoch 163/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9825 - loss: 0.4510 - val_accuracy: 0.9048 - val_loss: 0.7834
# Epoch 164/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9912 - loss: 0.4608 - val_accuracy: 0.9048 - val_loss: 0.7718
# Epoch 165/800
# 3/3 - 0s - 41ms/step - accuracy: 0.9737 - loss: 0.5068 - val_accuracy: 0.9048 - val_loss: 0.7700
# Epoch 166/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.4307 - val_accuracy: 0.9048 - val_loss: 0.8037
# Epoch 167/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.4339 - val_accuracy: 0.9048 - val_loss: 0.8009
# Epoch 168/800
# 3/3 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.4334 - val_accuracy: 0.9048 - val_loss: 0.7885
# Epoch 169/800
# 3/3 - 0s - 27ms/step - accuracy: 0.9649 - loss: 0.5396 - val_accuracy: 0.9048 - val_loss: 0.7457
# Epoch 170/800
# 3/3 - 0s - 30ms/step - accuracy: 0.9912 - loss: 0.4359 - val_accuracy: 0.9048 - val_loss: 0.7566
# Epoch 171/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.4539 - val_accuracy: 0.9048 - val_loss: 0.7544
# Epoch 172/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.4285 - val_accuracy: 0.9048 - val_loss: 0.7424
# Epoch 173/800
# 3/3 - 0s - 33ms/step - accuracy: 0.
800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.4067 - val_accuracy: 0.9524 - val_loss: 0.6865
# Epoch 268/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9912 - loss: 0.4103 - val_accuracy: 0.9048 - val_loss: 0.7104
# Epoch 269/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.4002 - val_accuracy: 0.9048 - val_loss: 0.7397
# Epoch 270/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.4065 - val_accuracy: 0.9048 - val_loss: 0.7615
# Epoch 271/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3988 - val_accuracy: 0.9048 - val_loss: 0.7660
# Epoch 272/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.4052 - val_accuracy: 0.9048 - val_loss: 0.7339
# Epoch 273/800
# 3/3 - 0s - 51ms/step - accuracy: 1.0000 - loss: 0.3972 - val_accuracy: 0.9048 - val_loss: 0.7112
# Epoch 274/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.4237 - val_accuracy: 0.9524 - val_loss: 0.7040
# Epoch 275/800
# 3/3 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.4036 - val_accuracy: 0.9048 - val_loss: 0.7044
# Epoch 276/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.3962 - val_accuracy: 0.9048 - val_loss: 0.7139
# Epoch 277/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.3978 - val_accuracy: 0.9048 - val_loss: 0.7139
# Epoch 278/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9912 - loss: 0.4133 - val_accuracy: 0.9524 - val_loss: 0.6962
# Epoch 279/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9912 - loss: 0.4259 - val_accuracy: 0.9048 - val_loss: 0.6961
# Epoch 280/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3972 - val_accuracy: 0.9048 - val_loss: 0.7180
# Epoch 281/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.4052 - val_accuracy: 0.9048 - val_loss: 0.7339
# Epoch 282/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.3985 - val_accuracy: 0.9524 - val_loss: 0.7016
# Epoch 283/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.3992 - val_accuracy: 0.9524 - val_loss: 0.6947
# Epoch 284/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.4054 - val_accuracy: 0.9524 - val_loss: 0.6999
# Epoch 285/800
# 3/3 - 0s - 50ms/step - accuracy: 1.0000 - loss: 0.3948 - val_accuracy: 0.9524 - val_loss: 0.7099
# Epoch 286/800
# 3/3 - 0s - 48ms/step - accuracy: 0.9912 - loss: 0.4052 - val_accuracy: 0.9524 - val_loss: 0.7114
# Epoch 287/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3915 - val_accuracy: 0.9524 - val_loss: 0.7200
# Epoch 288/800
# 3/3 - 0s - 37ms/step - accuracy: 0.9912 - loss: 0.4488 - val_accuracy: 0.9048 - val_loss: 0.7393
# Epoch 289/800
# 3/3 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.3907 - val_accuracy: 0.9048 - val_loss: 0.7582
# Epoch 290/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.4075 - val_accuracy: 0.9048 - val_loss: 0.7655
# Epoch 291/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.3968 - val_accuracy: 0.9048 - val_loss: 0.7865
# Epoch 292/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3909 - val_accuracy: 0.9048 - val_loss: 0.8253
# Epoch 293/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9912 - loss: 0.4013 - val_accuracy: 0.9048 - val_loss: 0.7932
# Epoch 294/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.4185 - val_accuracy: 0.9048 - val_loss: 0.7555
# Epoch 295/800
# 3/3 - 0s - 30ms/step - accuracy: 0.9912 - loss: 0.4001 - val_accuracy: 0.9048 - val_loss: 0.7201
# Epoch 296/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9825 - loss: 0.4110 - val_accuracy: 0.9048 - val_loss: 0.6989
# Epoch 297/800
# 3/3 - 0s - 46ms/step - accuracy: 0.9912 - loss: 0.3983 - val_accuracy: 0.9048 - val_loss: 0.7042
# Epoch 298/800
# 3/3 - 0s - 39ms/step - accuracy: 0.9912 - loss: 0.4117 - val_accuracy: 0.9524 - val_loss: 0.6831
# Epoch 299/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.3915 - val_accuracy: 0.9524 - val_loss: 0.6903
# Epoch 300/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3904 - val_accuracy: 0.9524 - val_loss: 0.6936
# Epoch 301/800
# 3/3 - 0s - 37ms/step - accuracy: 0.9912 - loss: 0.4090 - val_accuracy: 0.9524 - val_loss: 0.6998
# Epoch 302/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.3912 - val_accuracy: 0.9048 - val_loss: 0.7284
# Epoch 303/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.3890 - val_accuracy: 0.9048 - val_loss: 0.7402
# Epoch 304/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.3946 - val_accuracy: 0.9048 - val_loss: 0.7473
# Epoch 305/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.4127 - val_accuracy: 0.9048 - val_loss: 0.7113
# Epoch 306/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.3895 - val_accuracy: 0.9524 - val_loss: 0.7021
# Epoch 307/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.4134 - val_accuracy: 0.9524 - val_loss: 0.7027
# Epoch 308/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3896 - val_accuracy: 0.9048 - val_loss: 0.7509
# Epoch 309/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9737 - loss: 0.4157 - val_accuracy: 0.9048 - val_loss: 0.8407
# Epoch 310/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.4095 - val_accuracy: 0.9048 - val_loss: 0.8528
# Epoch 311/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9825 - loss: 0.4142 - val_accuracy: 0.9048 - val_loss: 0.8214
# Epoch 312/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.3932 - val_accuracy: 0.9048 - val_loss: 0.7308
# Epoch 313/800
# 3/3 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.3908 - val_accuracy: 0.9048 - val_loss: 0.6941
# Epoch 314/800
# 3/3 - 0s - 39ms/step - accuracy: 0.9825 - loss: 0.4341 - val_accuracy: 0.9048 - val_loss: 0.6772
# Epoch 315/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3892 - val_accuracy: 0.9048 - val_loss: 0.6889
# Epoch 316/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9825 - loss: 0.4578 - val_accuracy: 0.9048 - val_loss: 0.7620
# Epoch 317/800
# 3/3 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.3845 - val_accuracy: 0.9048 - val_loss: 0.7984
# Epoch 318/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9825 - loss: 0.4308 - val_accuracy: 0.9048 - val_loss: 0.7994
# Epoch 319/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3957 - val_accuracy: 0.9048 - val_loss: 0.7639
# Epoch 320/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.3998 - val_accuracy: 0.9048 - val_loss: 0.7212
# Epoch 321/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3959 - val_accuracy: 0.9524 - val_loss: 0.6690
# Epoch 322/800
# 3/3 - 0s - 42ms/step - accuracy: 0.9912 - loss: 0.4309 - val_accuracy: 0.9524 - val_loss: 0.6616
# Epoch 323/800
# 3/3 - 0s - 40ms/step - accuracy: 0.9912 - loss: 0.3950 - val_accuracy: 0.9524 - val_loss: 0.6610
# Epoch 324/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.4424 - val_accuracy: 0.9048 - val_loss: 0.6846
# Epoch 325/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9912 - loss: 0.4108 - val_accuracy: 0.9048 - val_loss: 0.7157
# Epoch 326/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.3896 - val_accuracy: 0.9048 - val_loss: 0.7267
# Epoch 327/800
# 3/3 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.4012 - val_accuracy: 0.9048 - val_loss: 0.7043
# Epoch 328/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.3943 - val_accuracy: 0.9524 - val_loss: 0.6551
# Epoch 329/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.4097 - val_accuracy: 0.9524 - val_loss: 0.6488
# Epoch 330/800
# 3/3 - 0s - 27ms/step - accuracy: 0.9912 - loss: 0.3904 - val_accuracy: 0.9524 - val_loss: 0.6468
# Epoch 331/800
# 3/3 - 0s - 28ms/step - accuracy: 0.9825 - loss: 0.4429 - val_accuracy: 0.9524 - val_loss: 0.6453
# Epoch 332/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9825 - loss: 0.4140 - val_accuracy: 0.9524 - val_loss: 0.6355
# Epoch 333/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.4105 - val_accuracy: 0.9048 - val_loss: 0.6581
# Epoch 334/800
# 3/3 - 0s - 48ms/step - accuracy: 0.9912 - loss: 0.3983 - val_accuracy: 0.9048 - val_loss: 0.6454
# Epoch 335/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.3980 - val_accuracy: 0.9048 - val_loss: 0.6463
# Epoch 336/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.3826 - val_accuracy: 0.9048 - val_loss: 0.6481
# Epoch 337/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3872 - val_accuracy: 0.9048 - val_loss: 0.6471
# Epoch 338/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.3922 - val_accuracy: 0.9048 - val_loss: 0.6381
# Epoch 339/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.3799 - val_accuracy: 0.9048 - val_loss: 0.6273
# Epoch 340/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.3805 - val_accuracy: 0.9048 - val_loss: 0.6252
# Epoch 341/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9825 - loss: 0.4218 - val_accuracy: 0.9048 - val_loss: 0.6301
# Epoch 342/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.3834 - val_accuracy: 0.9048 - val_loss: 0.6441
# Epoch 343/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.3874 - val_accuracy: 0.9048 - val_loss: 0.6894
# Epoch 344/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.3841 - val_accuracy: 0.9048 - val_loss: 0.7347
# Epoch 345/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3845 - val_accuracy: 0.9048 - val_loss: 0.7294
# Epoch 346/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.3806 - val_accuracy: 0.9048 - val_loss: 0.7154
# Epoch 347/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.3868 - val_accuracy: 0.9048 - val_loss: 0.6843
# Epoch 348/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.3770 - val_accuracy: 0.9524 - val_loss: 0.6594
# Epoch 349/800
# 3/3 - 0s - 37ms/step - accuracy: 0.9912 - loss: 0.4180 - val_accuracy: 0.9524 - val_loss: 0.6568
# Epoch 350/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.3809 - val_accuracy: 0.9524 - val_loss: 0.6481
# Epoch 351/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3819 - val_accuracy: 0.9524 - val_loss: 0.6428
# Epoch 352/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3809 - val_accuracy: 0.9048 - val_loss: 0.6486
# Epoch 353/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.4116 - val_accuracy: 0.9048 - val_loss: 0.6615
# Epoch 354/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3762 - val_accuracy: 0.9048 - val_loss: 0.6749
# Epoch 355/800
# 3/3 - 1s - 287ms/step - accuracy: 1.0000 - loss: 0.3776 - val_accuracy: 0.9048 - val_loss: 0.6865
# Epoch 356/800
# 3/3 - 1s - 359ms/step - accuracy: 1.0000 - loss: 0.3778 - val_accuracy: 0.9048 - val_loss: 0.6889
# Epoch 357/800
# 3/3 - 1s - 299ms/step - accuracy: 1.0000 - loss: 0.3775 - val_accuracy: 0.9048 - val_loss: 0.6852
# Epoch 358/800
# 3/3 - 1s - 328ms/step - accuracy: 0.9825 - loss: 0.4226 - val_accuracy: 0.9048 - val_loss: 0.6630
# Epoch 359/800
# 3/3 - 1s - 202ms/step - accuracy: 1.0000 - loss: 0.3761 - val_accuracy: 0.9524 - val_loss: 0.6434
# Epoch 360/800
# 3/3 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.3838 - val_accuracy: 0.9524 - val_loss: 0.6354
# Epoch 361/800
# 3/3 - 0s - 55ms/step - accuracy: 0.9737 - loss: 0.4142 - val_accuracy: 0.9048 - val_loss: 0.6418
# Epoch 362/800
# 3/3 - 0s - 62ms/step - accuracy: 0.9912 - loss: 0.3894 - val_accuracy: 0.9048 - val_loss: 0.6638
# Epoch 363/800
# 3/3 - 0s - 62ms/step - accuracy: 0.9912 - loss: 0.3854 - val_accuracy: 0.9048 - val_loss: 0.7118
# Epoch 364/800
# Epoch 385/800
# 3/3 - 0s - 67ms/step - accuracy: 0.9912 - loss: 0.4165 - val_accuracy: 0.9048 - val_loss: 0.6975
# Epoch 386/800
# 3/3 - 0s - 67ms/step - accuracy: 1.0000 - loss: 0.3729 - val_accuracy: 0.9048 - val_loss: 0.7022
# Epoch 387/800
# 3/3 - 0s - 71ms/step - accuracy: 0.9825 - loss: 0.4049 - val_accuracy: 0.9048 - val_loss: 0.6733
# Epoch 388/800
# 3/3 - 0s - 79ms/step - accuracy: 1.0000 - loss: 0.3764 - val_accuracy: 0.9048 - val_loss: 0.6937
# Epoch 389/800
# 3/3 - 0s - 59ms/step - accuracy: 0.9912 - loss: 0.3789 - val_accuracy: 0.9048 - val_loss: 0.6962
# Epoch 390/800
# 3/3 - 0s - 56ms/step - accuracy: 0.9912 - loss: 0.3828 - val_accuracy: 0.9048 - val_loss: 0.6739
# Epoch 391/800
# 3/3 - 0s - 54ms/step - accuracy: 0.9912 - loss: 0.3897 - val_accuracy: 0.9048 - val_loss: 0.6964
# Epoch 392/800
# 3/3 - 0s - 54ms/step - accuracy: 1.0000 - loss: 0.3754 - val_accuracy: 0.9048 - val_loss: 0.7691
# Epoch 393/800
# 3/3 - 0s - 59ms/step - accuracy: 0.9825 - loss: 0.4134 - val_accuracy: 0.9048 - val_loss: 0.7953
# Epoch 394/800
# 3/3 - 0s - 74ms/step - accuracy: 0.9912 - loss: 0.3780 - val_accuracy: 0.9048 - val_loss: 0.7388
# Epoch 395/800
# 3/3 - 0s - 69ms/step - accuracy: 1.0000 - loss: 0.3716 - val_accuracy: 0.9048 - val_loss: 0.6769
# Epoch 396/800
# 3/3 - 0s - 62ms/step - accuracy: 0.9912 - loss: 0.3954 - val_accuracy: 0.9048 - val_loss: 0.6605
# Epoch 397/800
# 3/3 - 0s - 66ms/step - accuracy: 1.0000 - loss: 0.3704 - val_accuracy: 0.9048 - val_loss: 0.6979
# Epoch 398/800
# 3/3 - 0s - 71ms/step - accuracy: 1.0000 - loss: 0.3782 - val_accuracy: 0.9048 - val_loss: 0.7536
# Epoch 399/800
# 3/3 - 0s - 99ms/step - accuracy: 0.9912 - loss: 0.3805 - val_accuracy: 0.9048 - val_loss: 0.7175
# Epoch 400/800
# 3/3 - 0s - 61ms/step - accuracy: 1.0000 - loss: 0.3707 - val_accuracy: 0.9048 - val_loss: 0.6979
# Epoch 401/800
# 3/3 - 0s - 61ms/step - accuracy: 0.9825 - loss: 0.4049 - val_accuracy: 0.9048 - val_loss: 0.6636
# Epoch 402/800
# 3/3 - 0s - 57ms/step - accuracy: 0.9912 - loss: 0.3757 - val_accuracy: 0.9048 - val_loss: 0.6481
# Epoch 403/800
# 3/3 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.3672 - val_accuracy: 0.9048 - val_loss: 0.6525
# Epoch 404/800
# 3/3 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.3711 - val_accuracy: 0.9048 - val_loss: 0.6559
# Epoch 405/800
# 3/3 - 0s - 91ms/step - accuracy: 0.9912 - loss: 0.3795 - val_accuracy: 0.9048 - val_loss: 0.6629
# Epoch 406/800
# 3/3 - 0s - 81ms/step - accuracy: 0.9912 - loss: 0.3949 - val_accuracy: 0.9048 - val_loss: 0.6691
# Epoch 407/800
# 3/3 - 0s - 121ms/step - accuracy: 1.0000 - loss: 0.3716 - val_accuracy: 0.9048 - val_loss: 0.6711
# Epoch 408/800
# 3/3 - 0s - 91ms/step - accuracy: 0.9912 - loss: 0.3800 - val_accuracy: 0.9048 - val_loss: 0.6670
# Epoch 409/800
# 3/3 - 0s - 68ms/step - accuracy: 1.0000 - loss: 0.3781 - val_accuracy: 0.9048 - val_loss: 0.6650
# Epoch 410/800
# 3/3 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.3682 - val_accuracy: 0.9524 - val_loss: 0.6646
# Epoch 411/800
# 3/3 - 0s - 56ms/step - accuracy: 1.0000 - loss: 0.3644 - val_accuracy: 0.9524 - val_loss: 0.6701
# Epoch 412/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.3909 - val_accuracy: 0.9524 - val_loss: 0.6781
# Epoch 413/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3682 - val_accuracy: 0.9048 - val_loss: 0.7122
# Epoch 414/800
# 3/3 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.3678 - val_accuracy: 0.9048 - val_loss: 0.7614
# Epoch 415/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3650 - val_accuracy: 0.9048 - val_loss: 0.7777
# Epoch 416/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3793 - val_accuracy: 0.9048 - val_loss: 0.7274
# Epoch 417/800
# 3/3 - 0s - 30ms/step - accuracy: 0.9912 - loss: 0.3786 - val_accuracy: 0.9048 - val_loss: 0.6836
# Epoch 418/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3690 - val_accuracy: 0.9048 - val_loss: 0.7034
# Epoch 419/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3713 - val_accuracy: 0.9048 - val_loss: 0.7061
# Epoch 420/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9912 - loss: 0.3710 - val_accuracy: 0.9048 - val_loss: 0.7239
# Epoch 421/800
# 3/3 - 0s - 52ms/step - accuracy: 0.9912 - loss: 0.3859 - val_accuracy: 0.9048 - val_loss: 0.7507
# Epoch 422/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9825 - loss: 0.4058 - val_accuracy: 0.9048 - val_loss: 0.7656
# Epoch 423/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3812 - val_accuracy: 0.9524 - val_loss: 0.6587
# Epoch 424/800
# 3/3 - 0s - 30ms/step - accuracy: 0.9912 - loss: 0.3707 - val_accuracy: 0.9524 - val_loss: 0.6574
# Epoch 425/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3668 - val_accuracy: 0.9524 - val_loss: 0.6650
# Epoch 426/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3646 - val_accuracy: 0.9524 - val_loss: 0.6640
# Epoch 427/800
# 3/3 - 0s - 42ms/step - accuracy: 0.9825 - loss: 0.3909 - val_accuracy: 0.9524 - val_loss: 0.6634
# Epoch 428/800
# 3/3 - 0s - 43ms/step - accuracy: 0.9825 - loss: 0.4141 - val_accuracy: 0.9524 - val_loss: 0.6792
# Epoch 429/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3744 - val_accuracy: 0.9524 - val_loss: 0.6856
# Epoch 430/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.4035 - val_accuracy: 0.9524 - val_loss: 0.6816
# Epoch 431/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9825 - loss: 0.3846 - val_accuracy: 0.9524 - val_loss: 0.6711
# Epoch 432/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3628 - val_accuracy: 0.9524 - val_loss: 0.6544
# Epoch 433/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3616 - val_accuracy: 0.9524 - val_loss: 0.6475
# Epoch 434/800
# ...
# Epoch 657/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3529 - val_accuracy: 0.9524 - val_loss: 0.5987
# Epoch 658/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3334 - val_accuracy: 0.9048 - val_loss: 0.6026
# Epoch 659/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3341 - val_accuracy: 0.9048 - val_loss: 0.6104
# Epoch 660/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9912 - loss: 0.3440 - val_accuracy: 0.9048 - val_loss: 0.6316
# Epoch 661/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3368 - val_accuracy: 0.9048 - val_loss: 0.6438
# Epoch 662/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3300 - val_accuracy: 0.9048 - val_loss: 0.6578
# Epoch 663/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.3352 - val_accuracy: 0.9048 - val_loss: 0.6986
# Epoch 664/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3296 - val_accuracy: 0.9048 - val_loss: 0.7168
# Epoch 665/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3240 - val_accuracy: 0.9048 - val_loss: 0.7192
# Epoch 666/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3250 - val_accuracy: 0.9048 - val_loss: 0.7274
# Epoch 667/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3353 - val_accuracy: 0.9048 - val_loss: 0.7035
# Epoch 668/800
# 3/3 - 0s - 58ms/step - accuracy: 0.9912 - loss: 0.3381 - val_accuracy: 0.9048 - val_loss: 0.6488
# Epoch 669/800
# 3/3 - 0s - 39ms/step - accuracy: 0.9912 - loss: 0.3532 - val_accuracy: 0.9048 - val_loss: 0.6811
# Epoch 670/800
# 3/3 - 0s - 41ms/step - accuracy: 0.9912 - loss: 0.3370 - val_accuracy: 0.9048 - val_loss: 0.7100
# Epoch 671/800
# 3/3 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.3250 - val_accuracy: 0.9048 - val_loss: 0.6873
# Epoch 672/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3240 - val_accuracy: 0.9048 - val_loss: 0.6660
# Epoch 673/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3236 - val_accuracy: 0.9048 - val_loss: 0.6559
# Epoch 674/800
# 3/3 - 0s - 37ms/step - accuracy: 0.9912 - loss: 0.3404 - val_accuracy: 0.9048 - val_loss: 0.6762
# Epoch 675/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3325 - val_accuracy: 0.9048 - val_loss: 0.6775
# Epoch 676/800
# 3/3 - 0s - 27ms/step - accuracy: 0.9737 - loss: 0.3817 - val_accuracy: 0.9048 - val_loss: 0.6811
# Epoch 677/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3379 - val_accuracy: 0.9048 - val_loss: 0.7427
# Epoch 678/800
# 3/3 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.3322 - val_accuracy: 0.9048 - val_loss: 0.7174
# Epoch 679/800
# 3/3 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.3265 - val_accuracy: 0.9048 - val_loss: 0.6594
# Epoch 680/800
# 3/3 - 0s - 42ms/step - accuracy: 0.9912 - loss: 0.3318 - val_accuracy: 0.9048 - val_loss: 0.6549
# Epoch 681/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3231 - val_accuracy: 0.9048 - val_loss: 0.6464
# Epoch 682/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3243 - val_accuracy: 0.9048 - val_loss: 0.6315
# Epoch 683/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3287 - val_accuracy: 0.9048 - val_loss: 0.6598
# Epoch 684/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3374 - val_accuracy: 0.9048 - val_loss: 0.7048
# Epoch 685/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3265 - val_accuracy: 0.9048 - val_loss: 0.7373
# Epoch 686/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.3245 - val_accuracy: 0.9048 - val_loss: 0.7406
# Epoch 687/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.3238 - val_accuracy: 0.9048 - val_loss: 0.7050
# Epoch 688/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.3244 - val_accuracy: 0.9048 - val_loss: 0.6460
# Epoch 689/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3311 - val_accuracy: 0.9524 - val_loss: 0.6283
# Epoch 690/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3320 - val_accuracy: 0.9524 - val_loss: 0.6304
# Epoch 691/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9912 - loss: 0.3370 - val_accuracy: 0.9048 - val_loss: 0.6344
# Epoch 692/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3257 - val_accuracy: 0.9048 - val_loss: 0.6764
# Epoch 693/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9912 - loss: 0.3309 - val_accuracy: 0.9048 - val_loss: 0.7812
# Epoch 694/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.3345 - val_accuracy: 0.9048 - val_loss: 0.7922
# Epoch 695/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3267 - val_accuracy: 0.9048 - val_loss: 0.7339
# Epoch 696/800
# 3/3 - 0s - 53ms/step - accuracy: 1.0000 - loss: 0.3269 - val_accuracy: 0.9048 - val_loss: 0.7045
# Epoch 697/800
# 3/3 - 0s - 40ms/step - accuracy: 0.9912 - loss: 0.3319 - val_accuracy: 0.9048 - val_loss: 0.6945
# Epoch 698/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3207 - val_accuracy: 0.9048 - val_loss: 0.6895
# Epoch 699/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3218 - val_accuracy: 0.9048 - val_loss: 0.6832
# Epoch 700/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3231 - val_accuracy: 0.9048 - val_loss: 0.6750
# Epoch 701/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3196 - val_accuracy: 0.9048 - val_loss: 0.6740
# Epoch 702/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3423 - val_accuracy: 0.9048 - val_loss: 0.6698
# Epoch 703/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3180 - val_accuracy: 0.9048 - val_loss: 0.6724
# Epoch 704/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.3334 - val_accuracy: 0.9048 - val_loss: 0.6999
# Epoch 705/800
# 3/3 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.3198 - val_accuracy: 0.9048 - val_loss: 0.7272
# Epoch 706/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9912 - loss: 0.3502 - val_accuracy: 0.9048 - val_loss: 0.7334
# Epoch 707/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.3176 - val_accuracy: 0.9048 - val_loss: 0.7294
# Epoch 708/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3181 - val_accuracy: 0.9048 - val_loss: 0.7270
# Epoch 709/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3324 - val_accuracy: 0.9048 - val_loss: 0.7260
# Epoch 710/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3226 - val_accuracy: 0.9048 - val_loss: 0.7445
# Epoch 711/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.3215 - val_accuracy: 0.9048 - val_loss: 0.7509
# Epoch 712/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.3230 - val_accuracy: 0.9048 - val_loss: 0.7493
# Epoch 713/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3174 - val_accuracy: 0.9048 - val_loss: 0.7446
# Epoch 714/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3166 - val_accuracy: 0.9048 - val_loss: 0.7341
# Epoch 715/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3170 - val_accuracy: 0.9048 - val_loss: 0.7230
# Epoch 716/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9912 - loss: 0.3241 - val_accuracy: 0.9048 - val_loss: 0.7260
# Epoch 717/800
# 3/3 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.3170 - val_accuracy: 0.9048 - val_loss: 0.7273
# Epoch 718/800
# 3/3 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.3221 - val_accuracy: 0.9048 - val_loss: 0.7255
# Epoch 719/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3194 - val_accuracy: 0.9048 - val_loss: 0.7324
# Epoch 720/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3171 - val_accuracy: 0.9048 - val_loss: 0.7319
# Epoch 721/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.3159 - val_accuracy: 0.9048 - val_loss: 0.7325
# Epoch 722/800
# 3/3 - 0s - 50ms/step - accuracy: 0.9912 - loss: 0.3399 - val_accuracy: 0.9048 - val_loss: 0.7480
# Epoch 723/800
# 3/3 - 0s - 40ms/step - accuracy: 0.9912 - loss: 0.3274 - val_accuracy: 0.9048 - val_loss: 0.7482
# Epoch 724/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.3337 - val_accuracy: 0.9048 - val_loss: 0.6997
# Epoch 725/800
# 3/3 - 0s - 43ms/step - accuracy: 0.9912 - loss: 0.3328 - val_accuracy: 0.9524 - val_loss: 0.6556
# Epoch 726/800
# 3/3 - 0s - 39ms/step - accuracy: 0.9912 - loss: 0.3322 - val_accuracy: 0.9524 - val_loss: 0.6628
# Epoch 727/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.3752 - val_accuracy: 0.9524 - val_loss: 0.6579
# Epoch 728/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.3149 - val_accuracy: 0.9524 - val_loss: 0.6379
# Epoch 729/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3208 - val_accuracy: 0.9524 - val_loss: 0.6284
# Epoch 730/800
# 3/3 - 0s - 40ms/step - accuracy: 0.9912 - loss: 0.3333 - val_accuracy: 0.9048 - val_loss: 0.7960
# Epoch 731/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.3508 - val_accuracy: 0.9048 - val_loss: 0.7652
# Epoch 732/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3154 - val_accuracy: 0.9048 - val_loss: 0.6826
# Epoch 733/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3180 - val_accuracy: 0.9524 - val_loss: 0.6515
# Epoch 734/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.3574 - val_accuracy: 0.9048 - val_loss: 0.6819
# Epoch 735/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3151 - val_accuracy: 0.9048 - val_loss: 0.7748
# Epoch 736/800
# 3/3 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.3221 - val_accuracy: 0.9048 - val_loss: 0.7992
# Epoch 737/800
# 3/3 - 0s - 39ms/step - accuracy: 0.9737 - loss: 0.4007 - val_accuracy: 0.9048 - val_loss: 0.6890
# Epoch 738/800
# 3/3 - 0s - 37ms/step - accuracy: 0.9825 - loss: 0.3564 - val_accuracy: 0.9524 - val_loss: 0.6401
# Epoch 739/800
# 3/3 - 0s - 51ms/step - accuracy: 0.9825 - loss: 0.3835 - val_accuracy: 0.9048 - val_loss: 0.6642
# Epoch 740/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9825 - loss: 0.3555 - val_accuracy: 0.9048 - val_loss: 0.7184
# Epoch 741/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3162 - val_accuracy: 0.9048 - val_loss: 0.7147
# Epoch 742/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.3433 - val_accuracy: 0.9048 - val_loss: 0.6844
# Epoch 743/800
# 3/3 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.3148 - val_accuracy: 0.9048 - val_loss: 0.6765
# Epoch 744/800
# 3/3 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.3159 - val_accuracy: 0.9048 - val_loss: 0.6739
# Epoch 745/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3184 - val_accuracy: 0.9048 - val_loss: 0.6614
# Epoch 746/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9825 - loss: 0.3629 - val_accuracy: 0.9048 - val_loss: 0.6474
# Epoch 747/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.3419 - val_accuracy: 0.9048 - val_loss: 0.6852
# Epoch 748/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3174 - val_accuracy: 0.9048 - val_loss: 0.6990
# Epoch 749/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.3236 - val_accuracy: 0.9048 - val_loss: 0.6617
# Epoch 750/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3166 - val_accuracy: 0.9048 - val_loss: 0.6279
# Epoch 751/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.3242 - val_accuracy: 0.9048 - val_loss: 0.6278
# Epoch 752/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9825 - loss: 0.3377 - val_accuracy: 0.9048 - val_loss: 0.6250
# Epoch 753/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9825 - loss: 0.3761 - val_accuracy: 0.9048 - val_loss: 0.6379
# Epoch 754/800
# 3/3 - 0s - 41ms/step - accuracy: 0.9912 - loss: 0.3638 - val_accuracy: 0.9048 - val_loss: 0.6439
# Epoch 755/800
# 3/3 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.3155 - val_accuracy: 0.9048 - val_loss: 0.6418
# Epoch 756/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.3162 - val_accuracy: 0.9048 - val_loss: 0.6703
# Epoch 757/800
# 3/3 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.3136 - val_accuracy: 0.9048 - val_loss: 0.7048
# Epoch 758/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3130 - val_accuracy: 0.9048 - val_loss: 0.7174
# Epoch 759/800
# 3/3 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.3173 - val_accuracy: 0.9048 - val_loss: 0.7065
# Epoch 760/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3230 - val_accuracy: 0.9048 - val_loss: 0.6591
# Epoch 761/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.3154 - val_accuracy: 0.9048 - val_loss: 0.6289
# Epoch 762/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3190 - val_accuracy: 0.9048 - val_loss: 0.6340
# Epoch 763/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9825 - loss: 0.3327 - val_accuracy: 0.9048 - val_loss: 0.6546
# Epoch 764/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.3276 - val_accuracy: 0.9048 - val_loss: 0.7228
# Epoch 765/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3174 - val_accuracy: 0.9048 - val_loss: 0.6773
# Epoch 766/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3161 - val_accuracy: 0.9048 - val_loss: 0.6812
# Epoch 767/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3157 - val_accuracy: 0.9048 - val_loss: 0.6902
# Epoch 768/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3113 - val_accuracy: 0.9048 - val_loss: 0.6911
# Epoch 769/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.3189 - val_accuracy: 0.9048 - val_loss: 0.7093
# Epoch 770/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.3110 - val_accuracy: 0.9048 - val_loss: 0.7226
# Epoch 771/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9737 - loss: 0.3652 - val_accuracy: 0.9048 - val_loss: 0.7175
# Epoch 772/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3121 - val_accuracy: 0.9048 - val_loss: 0.7154
# Epoch 773/800
# 3/3 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.3106 - val_accuracy: 0.9048 - val_loss: 0.7084
# Epoch 774/800
# 3/3 - 0s - 41ms/step - accuracy: 0.9825 - loss: 0.3373 - val_accuracy: 0.9048 - val_loss: 0.6927
# Epoch 775/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3175 - val_accuracy: 0.9048 - val_loss: 0.6445
# Epoch 776/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.3373 - val_accuracy: 0.9048 - val_loss: 0.6666
# Epoch 777/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3301 - val_accuracy: 0.9048 - val_loss: 0.6457
# Epoch 778/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3225 - val_accuracy: 0.9048 - val_loss: 0.6461
# Epoch 779/800
# 3/3 - 0s - 42ms/step - accuracy: 0.9825 - loss: 0.3511 - val_accuracy: 0.9048 - val_loss: 0.7096
# Epoch 780/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.3112 - val_accuracy: 0.9048 - val_loss: 0.7364
# Epoch 781/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.3104 - val_accuracy: 0.9048 - val_loss: 0.7315
# Epoch 782/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.3141 - val_accuracy: 0.9048 - val_loss: 0.6802
# Epoch 783/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3119 - val_accuracy: 0.9048 - val_loss: 0.6376
# Epoch 784/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9912 - loss: 0.3186 - val_accuracy: 0.9048 - val_loss: 0.6702
# Epoch 785/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.3088 - val_accuracy: 0.9048 - val_loss: 0.7348
# Epoch 786/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3153 - val_accuracy: 0.9048 - val_loss: 0.7649
# Epoch 787/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.3174 - val_accuracy: 0.9048 - val_loss: 0.7036
# Epoch 788/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.3109 - val_accuracy: 0.9048 - val_loss: 0.6613
# Epoch 789/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3099 - val_accuracy: 0.9048 - val_loss: 0.6475
# Epoch 790/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.3101 - val_accuracy: 0.9048 - val_loss: 0.6484
# Epoch 791/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.3362 - val_accuracy: 0.9048 - val_loss: 0.6347
# Epoch 792/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.3303 - val_accuracy: 0.9048 - val_loss: 0.6208
# Epoch 793/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.3333 - val_accuracy: 0.9048 - val_loss: 0.6265
# Epoch 794/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.3093 - val_accuracy: 0.9048 - val_loss: 0.6319
# Epoch 795/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.3305 - val_accuracy: 0.9048 - val_loss: 0.6489
# Epoch 796/800
# 3/3 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.3168 - val_accuracy: 0.9048 - val_loss: 0.7089
# Epoch 797/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9912 - loss: 0.3207 - val_accuracy: 0.9048 - val_loss: 0.7283
# Epoch 798/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3068 - val_accuracy: 0.9048 - val_loss: 0.7471
# Epoch 799/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.3082 - val_accuracy: 0.9048 - val_loss: 0.7607
# Epoch 800/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.3303 - val_accuracy: 0.9048 - val_loss: 0.6562

# %% [markdown]
# #### Plot the learning curves
#
# Let's now plot the loss and accuracy for the training and validation sets.

# %%
#Run this cell to plot the new accuracy vs epoch graph

try:
    plt.plot(reg_history.history['accuracy'])
    plt.plot(reg_history.history['val_accuracy'])
except KeyError:
    plt.plot(reg_history.history['acc'])
    plt.plot(reg_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the new loss vs epoch graph

plt.plot(reg_history.history['loss'])
plt.plot(reg_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# We can see that the regularisation has helped to reduce the overfitting of the network.
# You will now incorporate callbacks into a new training run that implements early stopping and learning rate reduction on plateaux.
#
# Fill in the function below so that:
#
# * It creates an `EarlyStopping` callback object and a `ReduceLROnPlateau` callback object
# * The early stopping callback is used and monitors validation loss with the mode set to `"min"` and patience of 30.
# * The learning rate reduction on plateaux is used with a learning rate factor of 0.2 and a patience of 20.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def get_callbacks():
    """
    This function should create and return a tuple (early_stopping, learning_rate_reduction) callbacks.
    The callbacks should be instantiated according to the above requirements.
    """

    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        mode="min",
        patience=30,
        restore_best_weights=True
    )

    learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=20
    )

    return early_stopping, learning_rate_reduction

# %% [markdown]
# Run the cell below to instantiate and train the regularised model with the callbacks.

# %%
call_model = get_regularised_model(train_data[0].shape, 0.3, 0.0001)
compile_model(call_model)
early_stopping, learning_rate_reduction = get_callbacks()
call_history = call_model.fit(train_data, train_targets, epochs=800, validation_split=0.15,
                         callbacks=[early_stopping, learning_rate_reduction], verbose=0)
# Out:
# 2025-11-26 21:40:26.865299: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:26.865378: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:26.865386: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:26.865445: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:26.865452: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:26.865474: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:26.865480: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:26.865491: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:27.756392: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_615', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-26 21:40:28.006733: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1230', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-11-26 21:40:28.651352: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1094', 36 bytes spill stores, 36 bytes spill loads
#
# 2025-11-26 21:40:28.880688: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_615', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-26 21:40:29.514023: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1936', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 21:40:30.259749: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1936', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 21:40:30.288857: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1960', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-11-26 21:40:30.400860: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1953', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-11-26 21:40:30.646907: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1936', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 21:40:36.011680: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:36.011744: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:36.011755: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:36.011819: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:36.011826: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 21:40:36.991006: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1600', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-26 21:40:37.223636: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_615', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 21:40:37.363619: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1094', 36 bytes spill stores, 36 bytes spill loads
#
# 2025-11-26 21:40:37.372224: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1094', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-26 21:40:37.966653: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1230', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-26 21:40:38.121845: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_615', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-26 21:40:39.224876: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1230', 24 bytes spill stores, 24 bytes spill loads

# %%
learning_rate_reduction.patience
# Out:
# 20

# %% [markdown]
# Finally, let's replot the accuracy and loss graphs for our new model.

# %%
try:
    plt.plot(call_history.history['accuracy'])
    plt.plot(call_history.history['val_accuracy'])
except KeyError:
    plt.plot(call_history.history['acc'])
    plt.plot(call_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(call_history.history['loss'])
plt.plot(call_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Evaluate the model on the test set

test_loss, test_acc = call_model.evaluate(test_data, test_targets, verbose=0)
print("Test loss: {:.3f}\nTest accuracy: {:.2f}%".format(test_loss, 100 * test_acc))
# Out:
# Test loss: 0.190
# Test accuracy: 93.33%

# %% [markdown]
# Congratulations for completing this programming assignment! In the next week of the course we will learn how to save and load pre-trained models.
