# %% [markdown]
# # Programming Assignment

# %% [markdown]
# ## Model validation on the Iris dataset

# %% [markdown]
# ### Instructions
#
# In this notebook, you will build, compile and fit a neural network model to the Iris dataset. You will also implement validation, regularisation and callbacks to improve your model.
#
# Some code cells are provided you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook
from numpy.random import seed
seed(8)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, model_selection
# %matplotlib inline

# If you would like to make further imports from tensorflow, add them here
# Out:
# 2025-11-26 23:50:09.861607: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 23:50:10.715392: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 23:50:12.995930: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# #### The Iris dataset
#
# In this assignment, you will use the [Iris dataset](https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html). It consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters. For a reference, see the following papers:
#
# - R. A. Fisher. "The use of multiple measurements in taxonomic problems". Annals of Eugenics. 7 (2): 179–188, 1936.
#
# Your goal is to construct a neural network that classifies each sample into the correct class, as well as applying validation and regularisation techniques.

# %% [markdown]
# #### Load and preprocess the data
#
# First read in the Iris dataset using `datasets.load_iris()`, and split the dataset into training and test sets.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def read_in_and_split_data(iris_data):
    """
    This function takes the Iris dataset as loaded by sklearn.datasets.load_iris(), and then
    splits so that the training set includes 90% of the full dataset, with the test set
    making up the remaining 10%.
    Your function should return a tuple (train_data, test_data, train_targets, test_targets)
    of appropriately split training and test data and targets.

    If you would like to import any further packages to aid you in this task, please do so in the
    Package Imports cell above.
    """
    
    train_data, test_data, train_targets, test_targets = model_selection.train_test_split(
        iris_data.data,
        iris_data.target,
        test_size=0.1
    )
    return (train_data, test_data, train_targets, test_targets)

# %%
# Run your function to generate the test and training data.

iris_data = datasets.load_iris()
train_data, test_data, train_targets, test_targets = read_in_and_split_data(iris_data)

# %% [markdown]
# We will now convert the training and test targets using a one hot encoder.

# %%
# Convert targets to a one-hot encoding

train_targets = tf.keras.utils.to_categorical(np.array(train_targets))
test_targets = tf.keras.utils.to_categorical(np.array(test_targets))

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# You can now construct a model to fit to the data. Using the Sequential API, build your model according to the following specifications:
#
# * The model should use the `input_shape` in the function argument to set the input size in the first layer.
# * The first layer should be a dense layer with 64 units.
# * The weights of the first layer should be initialised with the He uniform initializer.
# * The biases of the first layer should be all initially equal to one.
# * There should then be a further four dense layers, each with 128 units.
# * This should be followed with four dense layers, each with 64 units.
# * All of these Dense layers should use the ReLU activation function.
# * The output Dense layer should have 3 units and the softmax activation function.
#
# In total, the network should have 10 layers.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def get_model(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should return the model.
    """

    model = tf.keras.Sequential()

    # 1) First Dense layer: 64 units, He uniform, bias = 1, uses input_shape
    model.add(
        tf.keras.layers.Dense(
            64,
            activation='relu',
            input_shape=input_shape,
            kernel_initializer='he_uniform',
            bias_initializer=tf.keras.initializers.Constant(1.0),
        )
    )

    # 2) Next four Dense layers: 128 units, ReLU
    for _ in range(4):
        model.add(tf.keras.layers.Dense(128, activation='relu'))

    # 3) Next four Dense layers: 64 units, ReLU
    for _ in range(4):
        model.add(tf.keras.layers.Dense(64, activation='relu'))

    # 4) Output Dense layer: 3 units, softmax
    model.add(tf.keras.layers.Dense(3, activation='softmax'))

    return model

# %%
# Run your function to get the model

model = get_model(train_data[0].shape)
# Out:
# /home/nvidia/miniforge3/envs/rapids-25.10-cuda12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764222617.327941    1415 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5561 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# #### Compile the model
#
# You should now compile the model using the `compile` method. Remember that you need to specify an optimizer, a loss function and a metric to judge the performance of your model.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def compile_model(model):
    """
    This function takes in the model returned from your get_model function, and compiles it with an optimiser,
    loss function and metric.
    Compile the model using the Adam optimiser (with learning rate set to 0.0001),
    the categorical crossentropy loss function and accuracy as the only metric.
    Your function doesn't need to return anything; the model will be compiled in-place.
    """

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
    loss = 'categorical_crossentropy'
    metrics = ['accuracy']

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=metrics,
    )

# %%
# Run your function to compile the model

compile_model(model)

# %% [markdown]
# #### Fit the model to the training data
#
# Now you should train the model on the Iris dataset, using the model's `fit` method.
# * Run the training for a fixed number of epochs, given by the function's `epochs` argument.
# * Return the training history to be used for plotting the learning curves.
# * Set the batch size to 40.
# * Set the validation set to be 15% of the training set.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def train_model(model, train_data, train_targets, epochs):
    """
    This function should train the model for the given number of epochs on the
    train_data and train_targets.
    Your function should return the training history, as returned by model.fit.
    """
    history = model.fit(
        train_data,
        train_targets,
        validation_split = 0.15,
        epochs=epochs,
        verbose=2,
        batch_size=40
    )
    return history

# %%
# Run your function to train the model

history = train_model(model, train_data, train_targets, epochs=800)
# Out:
# Epoch 1/800
# 2025-11-26 23:50:19.962417: I external/local_xla/xla/service/service.cc:163] XLA service 0x7379fc006f40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-26 23:50:19.962443: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-11-26 23:50:20.003941: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-26 23:50:20.394913: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 2025-11-26 23:50:20.439551: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:20.439603: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:20.439613: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:20.439619: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:20.439642: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:20.439648: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:20.439656: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:20.439662: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:20.439689: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:20.439703: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:21.736461: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_411', 1120 bytes spill stores, 1120 bytes spill loads
#
# 2025-11-26 23:50:21.918641: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_418', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 23:50:22.311458: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 23:50:22.381831: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_418', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-26 23:50:22.739068: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-11-26 23:50:22.782129: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 476 bytes spill stores, 476 bytes spill loads
#
# 2025-11-26 23:50:23.357479: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-26 23:50:23.371095: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_446', 1112 bytes spill stores, 1112 bytes spill loads
#
# 2025-11-26 23:50:23.570016: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_696', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-26 23:50:23.614665: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_439', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 23:50:24.509444: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_702', 104 bytes spill stores, 104 bytes spill loads
#
# 2025-11-26 23:50:24.624383: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_696', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 23:50:24.797021: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_702', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 23:50:24.893593: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 23:50:24.959812: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 52 bytes spill stores, 52 bytes spill loads
#
# I0000 00:00:1764222627.355461    1510 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-26 23:50:27.704370: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:27.704432: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:27.704443: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:27.704450: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:27.704469: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:27.704475: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:27.704484: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:27.704490: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:27.704516: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:27.704530: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:28.836368: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 16 bytes spill stores, 16 bytes spill loads
#
# 2025-11-26 23:50:28.836885: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_439', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 23:50:28.841222: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_411', 1120 bytes spill stores, 1120 bytes spill loads
#
# 2025-11-26 23:50:28.865326: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_418', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 23:50:29.576791: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_418', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-26 23:50:29.797469: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 23:50:29.910888: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 23:50:29.931974: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_632', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-11-26 23:50:30.105817: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_446', 1112 bytes spill stores, 1112 bytes spill loads
#
# 2025-11-26 23:50:30.257951: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_696', 96 bytes spill stores, 96 bytes spill loads
#
# 2025-11-26 23:50:30.692460: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 476 bytes spill stores, 476 bytes spill loads
#
# 2025-11-26 23:50:30.797037: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_596', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-11-26 23:50:31.244935: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_702', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-26 23:50:31.564678: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_696', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 23:50:31.798736: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_702', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 23:50:34.113520: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:34.113593: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:50:35.334538: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 23:50:35.638064: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_115', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 23:50:35.681676: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_94', 48 bytes spill stores, 48 bytes spill loads
# 3/3 - 18s - 6s/step - accuracy: 0.3158 - loss: 1.0645 - val_accuracy: 0.5238 - val_loss: 1.0129
# Epoch 2/800
# 3/3 - 0s - 32ms/step - accuracy: 0.6491 - loss: 1.0237 - val_accuracy: 0.9048 - val_loss: 0.9915
# Epoch 3/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9035 - loss: 0.9938 - val_accuracy: 0.7619 - val_loss: 0.9674
# Epoch 4/800
# 3/3 - 0s - 33ms/step - accuracy: 0.7456 - loss: 0.9657 - val_accuracy: 0.6667 - val_loss: 0.9417
# Epoch 5/800
# 3/3 - 0s - 35ms/step - accuracy: 0.6842 - loss: 0.9380 - val_accuracy: 0.6667 - val_loss: 0.9166
# Epoch 6/800
# 3/3 - 0s - 35ms/step - accuracy: 0.6754 - loss: 0.9091 - val_accuracy: 0.6667 - val_loss: 0.8917
# Epoch 7/800
# 3/3 - 0s - 29ms/step - accuracy: 0.6842 - loss: 0.8798 - val_accuracy: 0.7143 - val_loss: 0.8691
# Epoch 8/800
# 3/3 - 0s - 22ms/step - accuracy: 0.7632 - loss: 0.8525 - val_accuracy: 0.7619 - val_loss: 0.8498
# Epoch 9/800
# 3/3 - 0s - 21ms/step - accuracy: 0.7982 - loss: 0.8239 - val_accuracy: 0.7619 - val_loss: 0.8271
# Epoch 10/800
# 3/3 - 0s - 21ms/step - accuracy: 0.8684 - loss: 0.7932 - val_accuracy: 0.7619 - val_loss: 0.8014
# Epoch 11/800
# 3/3 - 0s - 21ms/step - accuracy: 0.9123 - loss: 0.7582 - val_accuracy: 0.8571 - val_loss: 0.7735
# Epoch 12/800
# 3/3 - 0s - 54ms/step - accuracy: 0.9474 - loss: 0.7240 - val_accuracy: 0.8571 - val_loss: 0.7454
# Epoch 13/800
# 3/3 - 0s - 22ms/step - accuracy: 0.9474 - loss: 0.6891 - val_accuracy: 0.8571 - val_loss: 0.7169
# Epoch 14/800
# 3/3 - 0s - 22ms/step - accuracy: 0.9561 - loss: 0.6565 - val_accuracy: 0.9048 - val_loss: 0.6904
# Epoch 15/800
# 3/3 - 0s - 25ms/step - accuracy: 0.9561 - loss: 0.6235 - val_accuracy: 0.9048 - val_loss: 0.6657
# Epoch 16/800
# 3/3 - 0s - 22ms/step - accuracy: 0.9561 - loss: 0.5938 - val_accuracy: 0.9048 - val_loss: 0.6404
# Epoch 17/800
# 3/3 - 0s - 22ms/step - accuracy: 0.9737 - loss: 0.5644 - val_accuracy: 0.9048 - val_loss: 0.6148
# Epoch 18/800
# 3/3 - 0s - 21ms/step - accuracy: 0.9649 - loss: 0.5346 - val_accuracy: 0.9048 - val_loss: 0.5883
# Epoch 19/800
# 3/3 - 0s - 23ms/step - accuracy: 0.9649 - loss: 0.5071 - val_accuracy: 0.9048 - val_loss: 0.5652
# Epoch 20/800
# 3/3 - 0s - 24ms/step - accuracy: 0.9737 - loss: 0.4798 - val_accuracy: 0.9048 - val_loss: 0.5400
# Epoch 21/800
# 3/3 - 0s - 23ms/step - accuracy: 0.
800
# 3/3 - 0s - 27ms/step - accuracy: 0.9825 - loss: 0.0254 - val_accuracy: 0.9524 - val_loss: 0.3049
# Epoch 289/800
# 3/3 - 0s - 25ms/step - accuracy: 0.9825 - loss: 0.0209 - val_accuracy: 0.9524 - val_loss: 0.2913
# Epoch 290/800
# 3/3 - 0s - 28ms/step - accuracy: 0.9912 - loss: 0.0243 - val_accuracy: 0.9048 - val_loss: 0.2790
# Epoch 291/800
# 3/3 - 0s - 27ms/step - accuracy: 0.9912 - loss: 0.0256 - val_accuracy: 0.9524 - val_loss: 0.3067
# Epoch 292/800
# ...
# Epoch 657/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9524 - val_loss: 0.3878
# Epoch 658/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9524 - val_loss: 0.3905
# Epoch 659/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9048 - val_loss: 0.3959
# Epoch 660/800
# 3/3 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9524 - val_loss: 0.3890
# Epoch 661/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9524 - val_loss: 0.3886
# Epoch 662/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9048 - val_loss: 0.3954
# Epoch 663/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9048 - val_loss: 0.3933
# Epoch 664/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9524 - val_loss: 0.3901
# Epoch 665/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9524 - val_loss: 0.3902
# Epoch 666/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9524 - val_loss: 0.3928
# Epoch 667/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9524 - val_loss: 0.3909
# Epoch 668/800
# 3/3 - 0s - 24ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9524 - val_loss: 0.3908
# Epoch 669/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9524 - val_loss: 0.3921
# Epoch 670/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9048 - val_loss: 0.4024
# Epoch 671/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9524 - val_loss: 0.3927
# Epoch 672/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9524 - val_loss: 0.3909
# Epoch 673/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9524 - val_loss: 0.3921
# Epoch 674/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9048 - val_loss: 0.4135
# Epoch 675/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.9524 - val_loss: 0.3935
# Epoch 676/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9524 - val_loss: 0.3958
# Epoch 677/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.9524 - val_loss: 0.3957
# Epoch 678/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9048 - val_loss: 0.4028
# Epoch 679/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9524 - val_loss: 0.3921
# Epoch 680/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9524 - val_loss: 0.3920
# Epoch 681/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9048 - val_loss: 0.3966
# Epoch 682/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9048 - val_loss: 0.4096
# Epoch 683/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9524 - val_loss: 0.3942
# Epoch 684/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9048 - val_loss: 0.4050
# Epoch 685/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9048 - val_loss: 0.4045
# Epoch 686/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9524 - val_loss: 0.3956
# Epoch 687/800
# 3/3 - 0s - 38ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9524 - val_loss: 0.3931
# Epoch 688/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9524 - val_loss: 0.3984
# Epoch 689/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9048 - val_loss: 0.4066
# Epoch 690/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9524 - val_loss: 0.3953
# Epoch 691/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9524 - val_loss: 0.3952
# Epoch 692/800
# 3/3 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9524 - val_loss: 0.3952
# Epoch 693/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9048 - val_loss: 0.4145
# Epoch 694/800
# 3/3 - 0s - 24ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9524 - val_loss: 0.3983
# Epoch 695/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9524 - val_loss: 0.3956
# Epoch 696/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9048 - val_loss: 0.4095
# Epoch 697/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9524 - val_loss: 0.3998
# Epoch 698/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9524 - val_loss: 0.3965
# Epoch 699/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9048 - val_loss: 0.4009
# Epoch 700/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9048 - val_loss: 0.4068
# Epoch 701/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9524 - val_loss: 0.3984
# Epoch 702/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9524 - val_loss: 0.3998
# Epoch 703/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9524 - val_loss: 0.4003
# Epoch 704/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9524 - val_loss: 0.4016
# Epoch 705/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9524 - val_loss: 0.4015
# Epoch 706/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9524 - val_loss: 0.4002
# Epoch 707/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9524 - val_loss: 0.3999
# Epoch 708/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9048 - val_loss: 0.4088
# Epoch 709/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9524 - val_loss: 0.4012
# Epoch 710/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9524 - val_loss: 0.3995
# Epoch 711/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9048 - val_loss: 0.4062
# Epoch 712/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9048 - val_loss: 0.4051
# Epoch 713/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9524 - val_loss: 0.4008
# Epoch 714/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9524 - val_loss: 0.3999
# Epoch 715/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9048 - val_loss: 0.4281
# Epoch 716/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9524 - val_loss: 0.4009
# Epoch 717/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9524 - val_loss: 0.4019
# Epoch 718/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9524 - val_loss: 0.4016
# Epoch 719/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9048 - val_loss: 0.4319
# Epoch 720/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9524 - val_loss: 0.4044
# Epoch 721/800
# 3/3 - 0s - 28ms/step - accuracy: 0.9912 - loss: 0.0079 - val_accuracy: 0.9524 - val_loss: 0.4048
# Epoch 722/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.9048 - val_loss: 0.4474
# Epoch 723/800
# 3/3 - 0s - 27ms/step - accuracy: 0.9912 - loss: 0.0108 - val_accuracy: 0.9524 - val_loss: 0.4026
# Epoch 724/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9524 - val_loss: 0.4054
# Epoch 725/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9524 - val_loss: 0.4046
# Epoch 726/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9048 - val_loss: 0.4297
# Epoch 727/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9524 - val_loss: 0.4037
# Epoch 728/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9524 - val_loss: 0.4030
# Epoch 729/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9524 - val_loss: 0.4051
# Epoch 730/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9048 - val_loss: 0.4179
# Epoch 731/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9048 - val_loss: 0.4098
# Epoch 732/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9524 - val_loss: 0.4050
# Epoch 733/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9048 - val_loss: 0.4110
# Epoch 734/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9524 - val_loss: 0.4075
# Epoch 735/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9048 - val_loss: 0.4187
# Epoch 736/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9524 - val_loss: 0.4114
# Epoch 737/800
# 3/3 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9524 - val_loss: 0.4086
# Epoch 738/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9524 - val_loss: 0.4126
# Epoch 739/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9048 - val_loss: 0.4157
# Epoch 740/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9524 - val_loss: 0.4133
# Epoch 741/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9524 - val_loss: 0.4109
# Epoch 742/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9524 - val_loss: 0.4136
# Epoch 743/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9048 - val_loss: 0.4266
# Epoch 744/800
# 3/3 - 0s - 27ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9524 - val_loss: 0.4165
# Epoch 745/800
# 3/3 - 0s - 30ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9524 - val_loss: 0.4147
# Epoch 746/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9524 - val_loss: 0.4204
# Epoch 747/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9524 - val_loss: 0.4191
# Epoch 748/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.
800
# 3/3 - 0s - 25ms/step - accuracy: 0.9912 - loss: 0.0117 - val_accuracy: 0.9048 - val_loss: 0.4340
# Epoch 792/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9524 - val_loss: 0.4309
# Epoch 793/800
# 3/3 - 0s - 25ms/step - accuracy: 0.9912 - loss: 0.0119 - val_accuracy: 0.9524 - val_loss: 0.4230
# Epoch 794/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9048 - val_loss: 0.4889
# Epoch 795/800
# 3/3 - 0s - 25ms/step - accuracy: 0.9912 - loss: 0.0095 - val_accuracy: 0.9524 - val_loss: 0.4203
# Epoch 796/800
# 3/3 - 0s - 28ms/step - accuracy: 0.9912 - loss: 0.0100 - val_accuracy: 0.9524 - val_loss: 0.4211
# Epoch 797/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9048 - val_loss: 0.4359
# Epoch 798/800
# 3/3 - 0s - 25ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9048 - val_loss: 0.4342
# Epoch 799/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9524 - val_loss: 0.4177
# Epoch 800/800
# 3/3 - 0s - 26ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9524 - val_loss: 0.4178

# %% [markdown]
# #### Plot the learning curves
#
# We will now plot two graphs:
# * Epoch vs accuracy
# * Epoch vs loss

# %%
#Run this cell to plot the epoch vs accuracy graph

try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the epoch vs loss graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# Oh no! We have overfit our dataset. You should now try to now try to mitigate this overfitting.

# %% [markdown]
# #### Reducing overfitting in the model

# %% [markdown]
# You should now define a new regularised model.
# The specs for the regularised model are the same as our original model, with the addition of two dropout layers, weight decay, and a batch normalisation layer.
#
# In particular:
#
# * Add a dropout layer after the 3rd Dense layer
# * Then there should be two more Dense layers with 128 units before a batch normalisation layer
# * Following this, two more Dense layers with 64 units and then another Dropout layer
# * Two more Dense layers with 64 units and then the final 3-way softmax layer
# * Add weight decay (l2 kernel regularisation) in all Dense layers except the final softmax layer

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def get_regularised_model(input_shape, dropout_rate, weight_decay):
    """
    This function should build a regularised Sequential model according to the above specification.
    The dropout_rate argument in the function should be used to set the Dropout rate for all Dropout layers.
    L2 kernel regularisation (weight decay) should be added using the weight_decay argument to
    set the weight decay coefficient in all Dense layers that use L2 regularisation.
    Ensure the weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument input_shape.
    Your function should return the model.
    """

    model = tf.keras.Sequential()

    # L2 regulariser (weight decay) to reuse
    l2_reg = tf.keras.regularizers.l2(weight_decay)

    # 1) First Dense layer: 64 units, He uniform, bias = 1, with L2, uses input_shape
    model.add(
        tf.keras.layers.Dense(
            64,
            activation="relu",
            input_shape=input_shape,
            kernel_initializer="he_uniform",
            bias_initializer=tf.keras.initializers.Constant(1.0),
            kernel_regularizer=l2_reg,
        )
    )

    # 2) Next two Dense layers (2nd and 3rd Dense): 128 units, ReLU, with L2
    model.add(tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=l2_reg))
    model.add(tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=l2_reg))

    # Dropout after 3rd Dense layer
    model.add(tf.keras.layers.Dropout(dropout_rate))

    # 3) Two more Dense(128) layers before BatchNorm, with L2
    model.add(tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=l2_reg))
    model.add(tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=l2_reg))

    # Batch Normalisation layer
    model.add(tf.keras.layers.BatchNormalization())

    # 4) Two Dense(64) layers, with L2
    model.add(tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=l2_reg))
    model.add(tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=l2_reg))

    # Dropout after these two Dense(64) layers
    model.add(tf.keras.layers.Dropout(dropout_rate))

    # 5) Two more Dense(64) layers, with L2
    model.add(tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=l2_reg))
    model.add(tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=l2_reg))

    # 6) Final softmax output layer (no L2 here)
    model.add(tf.keras.layers.Dense(3, activation="softmax"))

    return model

# %% [markdown]
# #### Instantiate, compile and train the model

# %%
# Instantiate the model, using a dropout rate of 0.3 and weight decay coefficient of 0.001

reg_model = get_regularised_model(train_data[0].shape, 0.3, 0.001)

# %%
# Compile the model

compile_model(reg_model)

# %%
# Train the model

reg_history = train_model(reg_model, train_data, train_targets, epochs=800)
# Out:
# Epoch 1/800
# 2025-11-26 23:51:51.804628: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:51:51.804703: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:51:51.804714: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:51:51.804726: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:51:51.804744: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:51:53.117349: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1596', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 23:51:53.132773: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1596', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-11-26 23:51:53.202346: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1381', 36 bytes spill stores, 36 bytes spill loads
#
# 2025-11-26 23:51:53.539608: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1381', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-26 23:51:54.048267: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1956', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-26 23:51:54.382249: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1517', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-26 23:51:54.397583: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1949', 96 bytes spill stores, 96 bytes spill loads
#
# 2025-11-26 23:51:54.810299: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1596', 504 bytes spill stores, 504 bytes spill loads
#
# 2025-11-26 23:51:54.979344: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1949', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-11-26 23:51:54.986224: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1517', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-11-26 23:51:54.996638: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1956', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-11-26 23:51:59.833581: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:51:59.833637: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:51:59.833645: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:51:59.833665: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:51:59.833682: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:52:00.242809: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1596', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 23:52:00.700725: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1381', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-26 23:52:00.738700: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1517', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-26 23:52:01.173919: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1596', 20 bytes spill stores, 20 bytes spill loads
#
# 2025-11-26 23:52:01.372965: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1517', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-11-26 23:52:01.398979: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1381', 36 bytes spill stores, 36 bytes spill loads
#
# 2025-11-26 23:52:01.693820: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1949', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-11-26 23:52:02.280108: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1956', 96 bytes spill stores, 96 bytes spill loads
#
# 2025-11-26 23:52:02.280492: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1596', 504 bytes spill stores, 504 bytes spill loads
#
# 2025-11-26 23:52:02.364726: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1949', 92 bytes spill stores, 92 bytes spill loads
#
# 2025-11-26 23:52:02.447019: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1956', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-11-26 23:52:06.542162: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:52:06.984597: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_202', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-26 23:52:07.079711: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_202', 24 bytes spill stores, 24 bytes spill loads
# 3/3 - 19s - 6s/step - accuracy: 0.3684 - loss: 2.0204 - val_accuracy: 0.1905 - val_loss: 2.1249
# Epoch 2/800
# 3/3 - 0s - 30ms/step - accuracy: 0.3947 - loss: 2.0180 - val_accuracy: 0.1905 - val_loss: 2.1040
# Epoch 3/800
# 3/3 - 0s - 28ms/step - accuracy: 0.4211 - loss: 2.0030 - val_accuracy: 0.1905 - val_loss: 2.0838
# Epoch 4/800
# 3/3 - 0s - 33ms/step - accuracy: 0.4123 - loss: 2.0088 - val_accuracy: 0.1905 - val_loss: 2.0628
# Epoch 5/800
# 3/3 - 0s - 34ms/step - accuracy: 0.4123 - loss: 1.9573 - val_accuracy: 0.1905 - val_loss: 2.0460
# Epoch 6/800
# 3/3 - 0s - 30ms/step - accuracy: 0.3860 - loss: 1.9563 - val_accuracy: 0.1905 - val_loss: 2.0321
# Epoch 7/800
# 3/3 - 0s - 30ms/step - accuracy: 0.4298 - loss: 1.9334 - val_accuracy: 0.1905 - val_loss: 2.0191
# Epoch 8/800
# 3/3 - 0s - 32ms/step - accuracy: 0.3684 - loss: 1.9742 - val_accuracy: 0.1905 - val_loss: 2.0052
# Epoch 9/800
# 3/3 - 0s - 29ms/step - accuracy: 0.4474 - loss: 1.9723 - val_accuracy: 0.2857 - val_loss: 1.9923
# Epoch 10/800
# 3/3 - 0s - 28ms/step - accuracy: 0.4737 - loss: 1.9154 - val_accuracy: 0.4286 - val_loss: 1.9805
# Epoch 11/800
# 3/3 - 0s - 28ms/step - accuracy: 0.3596 - loss: 1.9515 - val_accuracy: 0.4762 - val_loss: 1.9700
# Epoch 12/800
# 3/3 - 0s - 29ms/step - accuracy: 0.5263 - loss: 1.8965 - val_accuracy: 0.5714 - val_loss: 1.9598
# Epoch 13/800
# 3/3 - 0s - 28ms/step - accuracy: 0.4474 - loss: 1.9335 - val_accuracy: 0.6190 - val_loss: 1.9495
# Epoch 14/800
# 3/3 - 0s - 28ms/step - accuracy: 0.5175 - loss: 1.9004 - val_accuracy: 0.6190 - val_loss: 1.9396
# Epoch 15/800
# 3/3 - 0s - 29ms/step - accuracy: 0.5175 - loss: 1.8820 - val_accuracy: 0.6190 - val_loss: 1.9299
# Epoch 16/800
# 3/3 - 0s - 28ms/step - accuracy: 0.4737 - loss: 1.8934 - val_accuracy: 0.6190 - val_loss: 1.9200
# Epoch 17/800
# 3/3 - 0s - 28ms/step - accuracy: 0.5000 - loss: 1.8986 - val_accuracy: 0.6190 - val_loss: 1.9124
# Epoch 18/800
# 3/3 - 0s - 33ms/step - accuracy: 0.5439 - loss: 1.8592 - val_accuracy: 0.6190 - val_loss: 1.9036
# Epoch 19/800
# 3/3 - 0s - 46ms/step - accuracy: 0.5351 - loss: 1.8568 - val_accuracy: 0.6190 - val_loss: 1.8945
# Epoch 20/800
# 3/3 - 0s - 27ms/step - accuracy: 0.5965 - loss: 1.8480 - val_accuracy: 0.6190 - val_loss: 1.8831
# Epoch 21/800
# 3/3 - 0s - 47ms/step - accuracy: 0.5175 - loss: 1.8384 - val_accuracy: 0.6190 - val_loss: 1.8695
# Epoch 22/800
# 3/3 - 0s - 28ms/step - accuracy: 0.5877 - loss: 1.8306 - val_accuracy: 0.6190 - val_loss: 1.8554
# Epoch 23/800
# 3/3 - 0s - 28ms/step - accuracy: 0.5789 - loss: 1.8478 - val_accuracy: 0.6190 - val_loss: 1.8421
# Epoch 24/800
# 3/3 - 0s - 26ms/step - accuracy: 0.6228 - loss: 1.8049 - val_accuracy: 0.6190 - val_loss: 1.8284
# Epoch 25/800
# 3/3 - 0s - 27ms/step - accuracy: 0.5877 - loss: 1.7760 - val_accuracy: 0.6190 - val_loss: 1.8135
# Epoch 26/800
# 3/3 - 0s - 25ms/step - accuracy: 0.6316 - loss: 1.7352 - val_accuracy: 0.6190 - val_loss: 1.7978
# Epoch 27/800
# 3/3 - 0s - 25ms/step - accuracy: 0.5877 - loss: 1.8000 - val_accuracy: 0.6190 - val_loss: 1.7790
# Epoch 28/800
# 3/3 - 0s - 31ms/step - accuracy: 0.5614 - loss: 1.7768 - val_accuracy: 0.6190 - val_loss: 1.7579
# Epoch 29/800
# 3/3 - 0s - 28ms/step - accuracy: 0.6140 - loss: 1.7399 - val_accuracy: 0.6190 - val_loss: 1.7354
# Epoch 30/800
# 3/3 - 0s - 30ms/step - accuracy: 0.6404 - loss: 1.7294 - val_accuracy: 0.6190 - val_loss: 1.7144
# Epoch 31/800
# 3/3 - 0s - 25ms/step - accuracy: 0.6579 - loss: 1.7035 - val_accuracy: 0.6190 - val_loss: 1.6953
# Epoch 32/800
# 3/3 - 0s - 27ms/step - accuracy: 0.6579 - loss: 1.6636 - val_accuracy: 0.6190 - val_loss: 1.6760
# Epoch 33/800
# 3/3 - 0s - 26ms/step - accuracy: 0.7193 - loss: 1.6395 - val_accuracy: 0.6190 - val_loss: 1.6578
# Epoch 34/800
# 3/3 - 0s - 27ms/step - accuracy: 0.6842 - loss: 1.6347 - val_accuracy: 0.6190 - val_loss: 1.6407
# Epoch 35/800
# 3/3 - 0s - 25ms/step - accuracy: 0.7193 - loss: 1.6047 - val_accuracy: 0.6190 - val_loss: 1.6229
# Epoch 36/800
# 3/3 - 0s - 34ms/step - accuracy: 0.7018 - loss: 1.6215 - val_accuracy: 0.6190 - val_loss: 1.6068
# Epoch 37/800
# 3/3 - 0s - 43ms/step - accuracy: 0.7368 - loss: 1.5649 - val_accuracy: 0.6190 - val_loss: 1.5917
# Epoch 38/800
# 3/3 - 0s - 38ms/step - accuracy: 0.7368 - loss: 1.5649 - val_accuracy: 0.6190 - val_loss: 1.5766
# Epoch 39/800
# 3/3 - 0s - 33ms/step - accuracy: 0.7368 - loss: 1.5251 - val_accuracy: 0.6190 - val_loss: 1.5614
# Epoch 40/800
# 3/3 - 0s - 36ms/step - accuracy: 0.6667 - loss: 1.5901 - val_accuracy: 0.6190 - val_loss: 1.5454
# Epoch 41/800
# 3/3 - 0s - 25ms/step - accuracy: 0.6842 - loss: 1.5319 - val_accuracy: 0.6190 - val_loss: 1.5291
# Epoch 42/800
# 3/3 - 0s - 26ms/step - accuracy: 0.7368 - loss: 1.5076 - val_accuracy: 0.6190 - val_loss: 1.5136
# Epoch 43/800
# 3/3 - 0s - 33ms/step - accuracy: 0.7193 - loss: 1.5075 - val_accuracy: 0.6190 - val_loss: 1.4984
# Epoch 44/800
# 3/3 - 0s - 38ms/step - accuracy: 0.7456 - loss: 1.4995 - val_accuracy: 0.6190 - val_loss: 1.4828
# Epoch 45/800
# 3/3 - 0s - 30ms/step - accuracy: 0.7368 - loss: 1.4776 - val_accuracy: 0.6667 - val_loss: 1.4690
# Epoch 46/800
# 3/3 - 0s - 33ms/step - accuracy: 0.7281 - loss: 1.4747 - val_accuracy: 0.6667 - val_loss: 1.4567
# Epoch 47/800
# 3/3 - 0s - 27ms/step - accuracy: 0.7281 - loss: 1.4566 - val_accuracy: 0.6667 - val_loss: 1.4448
# Epoch 48/800
# 3/3 - 0s - 31ms/step - accuracy: 0.7018 - loss: 1.4243 - val_accuracy: 0.6667 - val_loss: 1.4334
# Epoch 49/800
# 3/3 - 0s - 32ms/step - accuracy: 0.7193 - loss: 1.4391 - val_accuracy: 0.6667 - val_loss: 1.4226
# Epoch 50/800
# 3/3 - 0s - 41ms/step - accuracy: 0.7281 - loss: 1.4257 - val_accuracy: 0.6667 - val_loss: 1.4126
# Epoch 51/800
# 3/3 - 0s - 33ms/step - accuracy: 0.7281 - loss: 1.4136 - val_accuracy: 0.7143 - val_loss: 1.4035
# Epoch 52/800
# 3/3 - 0s - 35ms/step - accuracy: 0.7456 - loss: 1.4231 - val_accuracy: 0.7143 - val_loss: 1.3950
# Epoch 53/800
# 3/3 - 0s - 38ms/step - accuracy: 0.7719 - loss: 1.3659 - val_accuracy: 0.7143 - val_loss: 1.3873
# Epoch 54/800
# 3/3 - 0s - 31ms/step - accuracy: 0.7193 - loss: 1.3947 - val_accuracy: 0.7143 - val_loss: 1.3799
# Epoch 55/800
# 3/3 - 0s - 32ms/step - accuracy: 0.7632 - loss: 1.3800 - val_accuracy: 0.7143 - val_loss: 1.3723
# Epoch 56/800
# 3/3 - 0s - 29ms/step - accuracy: 0.7895 - loss: 1.3561 - val_accuracy: 0.7143 - val_loss: 1.3653
# Epoch 57/800
# 3/3 - 0s - 25ms/step - accuracy: 0.8158 - loss: 1.2989 - val_accuracy: 0.7143 - val_loss: 1.3576
# Epoch 58/800
# 3/3 - 0s - 26ms/step - accuracy: 0.8509 - loss: 1.3000 - val_accuracy: 0.7143 - val_loss: 1.3489
# Epoch 59/800
# 3/3 - 0s - 26ms/step - accuracy: 0.8421 - loss: 1.2916 - val_accuracy: 0.7143 - val_loss: 1.3401
# Epoch 60/800
# 3/3 - 0s - 29ms/step - accuracy: 0.8070 - loss: 1.3173 - val_accuracy: 0.7143 - val_loss: 1.3308
# Epoch 61/800
# 3/3 - 0s - 26ms/step - accuracy: 0.8246 - loss: 1.3092 - val_accuracy: 0.7619 - val_loss: 1.3212
# Epoch 62/800
# 3/3 - 0s - 30ms/step - accuracy: 0.7719 - loss: 1.3130 - val_accuracy: 0.7619 - val_loss: 1.3110
# Epoch 63/800
# 3/3 - 0s - 26ms/step - accuracy: 0.7895 - loss: 1.2993 - val_accuracy: 0.7619 - val_loss: 1.3008
# Epoch 64/800
# 3/3 - 0s - 38ms/step - accuracy: 0.8596 - loss: 1.2516 - val_accuracy: 0.7619 - val_loss: 1.2910
# Epoch 65/800
# 3/3 - 0s - 39ms/step - accuracy: 0.8158 - loss: 1.2746 - val_accuracy: 0.7619 - val_loss: 1.2813
# Epoch 66/800
# 3/3 - 0s - 31ms/step - accuracy: 0.8860 - loss: 1.2342 - val_accuracy: 0.8095 - val_loss: 1.2703
# Epoch 67/800
# 3/3 - 0s - 33ms/step - accuracy: 0.8772 - loss: 1.2241 - val_accuracy: 0.8095 - val_loss: 1.2602
# Epoch 68/800
# 3/3 - 0s - 32ms/step - accuracy: 0.8421 - loss: 1.2538 - val_accuracy: 0.8571 - val_loss: 1.2496
# Epoch 69/800
# 3/3 - 0s - 32ms/step - accuracy: 0.8421 - loss: 1.2339 - val_accuracy: 0.8571 - val_loss: 1.2391
# Epoch 70/800
# 3/3 - 0s - 33ms/step - accuracy: 0.8772 - loss: 1.2244 - val_accuracy: 0.8571 - val_loss: 1.2293
# Epoch 71/800
# 3/3 - 0s - 32ms/step - accuracy: 0.8421 - loss: 1.2381 - val_accuracy: 0.9048 - val_loss: 1.2193
# Epoch 72/800
# 3/3 - 0s - 31ms/step - accuracy: 0.8070 - loss: 1.2458 - val_accuracy: 0.9048 - val_loss: 1.2100
# Epoch 73/800
# 3/3 - 0s - 31ms/step - accuracy: 0.8860 - loss: 1.1877 - val_accuracy: 0.9048 - val_loss: 1.1985
# Epoch 74/800
# 3/3 - 0s - 35ms/step - accuracy: 0.8684 - loss: 1.1987 - val_accuracy: 0.9048 - val_loss: 1.1859
# Epoch 75/800
# 3/3 - 0s - 43ms/step - accuracy: 0.9211 - loss: 1.1504 - val_accuracy: 0.9048 - val_loss: 1.1726
# Epoch 76/800
# 3/3 - 0s - 33ms/step - accuracy: 0.8421 - loss: 1.2002 - val_accuracy: 0.9048 - val_loss: 1.1594
# Epoch 77/800
# 3/3 - 0s - 28ms/step - accuracy: 0.8509 - loss: 1.1671 - val_accuracy: 0.9048 - val_loss: 1.1477
# Epoch 78/800
# 3/3 - 0s - 26ms/step - accuracy: 0.8596 - loss: 1.1668 - val_accuracy: 0.9524 - val_loss: 1.1357
# Epoch 79/800
# 3/3 - 0s - 26ms/step - accuracy: 0.8772 - loss: 1.1289 - val_accuracy: 0.9524 - val_loss: 1.1248
# Epoch 80/800
# 3/3 - 0s - 28ms/step - accuracy: 0.8860 - loss: 1.1521 - val_accuracy: 0.9524 - val_loss: 1.1181
# Epoch 81/800
# 3/3 - 0s - 27ms/step - accuracy: 0.8684 - loss: 1.1688 - val_accuracy: 0.9524 - val_loss: 1.1112
# Epoch 82/800
# 3/3 - 0s - 26ms/step - accuracy: 0.
800
# 3/3 - 0s - 31ms/step - accuracy: 0.9825 - loss: 0.5565 - val_accuracy: 0.9048 - val_loss: 0.8780
# Epoch 664/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.5362 - val_accuracy: 0.9048 - val_loss: 0.8835
# Epoch 665/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.5340 - val_accuracy: 0.9048 - val_loss: 0.8810
# Epoch 666/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9649 - loss: 0.5995 - val_accuracy: 0.9048 - val_loss: 0.8569
# Epoch 667/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.5366 - val_accuracy: 0.9048 - val_loss: 0.8692
# Epoch 668/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.5317 - val_accuracy: 0.9048 - val_loss: 0.8656
# Epoch 669/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.5332 - val_accuracy: 0.9048 - val_loss: 0.8374
# Epoch 670/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9912 - loss: 0.5498 - val_accuracy: 0.9524 - val_loss: 0.8132
# Epoch 671/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.5264 - val_accuracy: 0.9524 - val_loss: 0.8112
# Epoch 672/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.5434 - val_accuracy: 0.9524 - val_loss: 0.8192
# Epoch 673/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9825 - loss: 0.5513 - val_accuracy: 0.9524 - val_loss: 0.8134
# Epoch 674/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9825 - loss: 0.5496 - val_accuracy: 0.9524 - val_loss: 0.8171
# Epoch 675/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9912 - loss: 0.5481 - val_accuracy: 0.9048 - val_loss: 0.8404
# Epoch 676/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.5385 - val_accuracy: 0.9048 - val_loss: 0.8532
# Epoch 677/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.5339 - val_accuracy: 0.9048 - val_loss: 0.8524
# Epoch 678/800
# 3/3 - 0s - 41ms/step - accuracy: 0.9912 - loss: 0.5365 - val_accuracy: 0.9524 - val_loss: 0.8494
# Epoch 679/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.5474 - val_accuracy: 0.9524 - val_loss: 0.8503
# Epoch 680/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9825 - loss: 0.5560 - val_accuracy: 0.9524 - val_loss: 0.8538
# Epoch 681/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.5290 - val_accuracy: 0.9524 - val_loss: 0.8537
# Epoch 682/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.5466 - val_accuracy: 0.9524 - val_loss: 0.8547
# Epoch 683/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.5282 - val_accuracy: 0.9524 - val_loss: 0.8500
# Epoch 684/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.5316 - val_accuracy: 0.9524 - val_loss: 0.8475
# Epoch 685/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.5505 - val_accuracy: 0.9048 - val_loss: 0.8483
# Epoch 686/800
# 3/3 - 0s - 45ms/step - accuracy: 0.9912 - loss: 0.5496 - val_accuracy: 0.9048 - val_loss: 0.8577
# Epoch 687/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.5248 - val_accuracy: 0.9048 - val_loss: 0.8670
# Epoch 688/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.5243 - val_accuracy: 0.9048 - val_loss: 0.8687
# Epoch 689/800
# 3/3 - 0s - 30ms/step - accuracy: 0.
800
# 3/3 - 0s - 34ms/step - accuracy: 0.9912 - loss: 0.5347 - val_accuracy: 0.9524 - val_loss: 0.8893
# Epoch 740/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.5104 - val_accuracy: 0.9524 - val_loss: 0.8732
# Epoch 741/800
# 3/3 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.5126 - val_accuracy: 0.9048 - val_loss: 0.8809
# Epoch 742/800
# 3/3 - 0s - 38ms/step - accuracy: 0.9912 - loss: 0.5278 - val_accuracy: 0.9048 - val_loss: 0.8744
# Epoch 743/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.5204 - val_accuracy: 0.9524 - val_loss: 0.8599
# Epoch 744/800
# 3/3 - 0s - 40ms/step - accuracy: 0.9825 - loss: 0.5515 - val_accuracy: 0.9524 - val_loss: 0.8510
# Epoch 745/800
# 3/3 - 0s - 37ms/step - accuracy: 0.9912 - loss: 0.5219 - val_accuracy: 0.9524 - val_loss: 0.8563
# Epoch 746/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.5132 - val_accuracy: 0.9524 - val_loss: 0.8670
# Epoch 747/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9825 - loss: 0.5281 - val_accuracy: 0.9524 - val_loss: 0.8691
# Epoch 748/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9912 - loss: 0.5173 - val_accuracy: 0.9524 - val_loss: 0.8535
# Epoch 749/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.5201 - val_accuracy: 0.9524 - val_loss: 0.8311
# Epoch 750/800
# 3/3 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.5082 - val_accuracy: 0.9524 - val_loss: 0.8196
# Epoch 751/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.5125 - val_accuracy: 0.9524 - val_loss: 0.8214
# Epoch 752/800
# 3/3 - 0s - 44ms/step - accuracy: 0.9825 - loss: 0.5409 - val_accuracy: 0.9524 - val_loss: 0.8277
# Epoch 753/800
# 3/3 - 0s - 44ms/step - accuracy: 0.9825 - loss: 0.5277 - val_accuracy: 0.9524 - val_loss: 0.8387
# Epoch 754/800
# 3/3 - 0s - 33ms/step - accuracy: 0.9737 - loss: 0.5626 - val_accuracy: 0.9524 - val_loss: 0.8510
# Epoch 755/800
# 3/3 - 0s - 34ms/step - accuracy: 0.9912 - loss: 0.5227 - val_accuracy: 0.9524 - val_loss: 0.8496
# Epoch 756/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9825 - loss: 0.5298 - val_accuracy: 0.9524 - val_loss: 0.8402
# Epoch 757/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.5125 - val_accuracy: 0.9048 - val_loss: 0.8488
# Epoch 758/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.5214 - val_accuracy: 0.9048 - val_loss: 0.8534
# Epoch 759/800
# 3/3 - 0s - 36ms/step - accuracy: 0.9912 - loss: 0.5162 - val_accuracy: 0.9524 - val_loss: 0.8415
# Epoch 760/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9737 - loss: 0.5441 - val_accuracy: 0.9524 - val_loss: 0.8359
# Epoch 761/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9825 - loss: 0.5428 - val_accuracy: 0.9048 - val_loss: 0.8603
# Epoch 762/800
# 3/3 - 0s - 31ms/step - accuracy: 1.0000 - loss: 0.5042 - val_accuracy: 0.9048 - val_loss: 0.8681
# Epoch 763/800
# 3/3 - 0s - 28ms/step - accuracy: 0.9912 - loss: 0.5164 - val_accuracy: 0.9048 - val_loss: 0.8318
# Epoch 764/800
# 3/3 - 0s - 56ms/step - accuracy: 1.0000 - loss: 0.5127 - val_accuracy: 0.9524 - val_loss: 0.8048
# Epoch 765/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.5136 - val_accuracy: 0.9524 - val_loss: 0.8045
# Epoch 766/800
# 3/3 - 0s - 28ms/step - accuracy: 0.9912 - loss: 0.5100 - val_accuracy: 0.9524 - val_loss: 0.7997
# Epoch 767/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.5115 - val_accuracy: 0.9524 - val_loss: 0.7897
# Epoch 768/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9825 - loss: 0.5314 - val_accuracy: 0.9524 - val_loss: 0.7861
# Epoch 769/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9825 - loss: 0.5507 - val_accuracy: 0.9524 - val_loss: 0.7846
# Epoch 770/800
# 3/3 - 0s - 39ms/step - accuracy: 0.9912 - loss: 0.5204 - val_accuracy: 0.9048 - val_loss: 0.8024
# Epoch 771/800
# 3/3 - 0s - 45ms/step - accuracy: 0.9912 - loss: 0.5264 - val_accuracy: 0.9048 - val_loss: 0.7913
# Epoch 772/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.5100 - val_accuracy: 0.9524 - val_loss: 0.7960
# Epoch 773/800
# 3/3 - 0s - 39ms/step - accuracy: 0.9912 - loss: 0.5179 - val_accuracy: 0.9524 - val_loss: 0.7958
# Epoch 774/800
# 3/3 - 0s - 43ms/step - accuracy: 0.9912 - loss: 0.5160 - val_accuracy: 0.9524 - val_loss: 0.8003
# Epoch 775/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.5033 - val_accuracy: 0.9524 - val_loss: 0.8142
# Epoch 776/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.5168 - val_accuracy: 0.9524 - val_loss: 0.8204
# Epoch 777/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9912 - loss: 0.5275 - val_accuracy: 0.9524 - val_loss: 0.8115
# Epoch 778/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.5058 - val_accuracy: 0.9048 - val_loss: 0.8261
# Epoch 779/800
# 3/3 - 0s - 31ms/step - accuracy: 0.9737 - loss: 0.5326 - val_accuracy: 0.9048 - val_loss: 0.9520
# Epoch 780/800
# 3/3 - 0s - 35ms/step - accuracy: 0.9737 - loss: 0.5572 - val_accuracy: 0.9048 - val_loss: 0.9261
# Epoch 781/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.5039 - val_accuracy: 0.9048 - val_loss: 0.8380
# Epoch 782/800
# 3/3 - 0s - 37ms/step - accuracy: 1.0000 - loss: 0.4989 - val_accuracy: 0.9524 - val_loss: 0.8108
# Epoch 783/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.5399 - val_accuracy: 0.9524 - val_loss: 0.8075
# Epoch 784/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.5112 - val_accuracy: 0.9524 - val_loss: 0.8072
# Epoch 785/800
# 3/3 - 0s - 36ms/step - accuracy: 1.0000 - loss: 0.5010 - val_accuracy: 0.9524 - val_loss: 0.8046
# Epoch 786/800
# 3/3 - 0s - 32ms/step - accuracy: 1.0000 - loss: 0.5046 - val_accuracy: 0.9524 - val_loss: 0.8031
# Epoch 787/800
# 3/3 - 0s - 28ms/step - accuracy: 1.0000 - loss: 0.5025 - val_accuracy: 0.9524 - val_loss: 0.8029
# Epoch 788/800
# 3/3 - 0s - 29ms/step - accuracy: 1.0000 - loss: 0.5066 - val_accuracy: 0.9524 - val_loss: 0.8073
# Epoch 789/800
# 3/3 - 0s - 30ms/step - accuracy: 0.9825 - loss: 0.5467 - val_accuracy: 0.9524 - val_loss: 0.8077
# Epoch 790/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.5008 - val_accuracy: 0.9524 - val_loss: 0.8066
# Epoch 791/800
# 3/3 - 0s - 32ms/step - accuracy: 0.9912 - loss: 0.5433 - val_accuracy: 0.9524 - val_loss: 0.7985
# Epoch 792/800
# 3/3 - 0s - 29ms/step - accuracy: 0.9737 - loss: 0.5296 - val_accuracy: 0.9524 - val_loss: 0.7899
# Epoch 793/800
# 3/3 - 0s - 28ms/step - accuracy: 0.9912 - loss: 0.5121 - val_accuracy: 0.9524 - val_loss: 0.7852
# Epoch 794/800
# 3/3 - 0s - 60ms/step - accuracy: 0.9912 - loss: 0.5057 - val_accuracy: 0.9048 - val_loss: 0.7855
# Epoch 795/800
# 3/3 - 0s - 47ms/step - accuracy: 0.9912 - loss: 0.5105 - val_accuracy: 0.9048 - val_loss: 0.7847
# Epoch 796/800
# 3/3 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.4969 - val_accuracy: 0.9048 - val_loss: 0.7890
# Epoch 797/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.4997 - val_accuracy: 0.9524 - val_loss: 0.7886
# Epoch 798/800
# 3/3 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.4992 - val_accuracy: 0.9524 - val_loss: 0.7899
# Epoch 799/800
# 3/3 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.5065 - val_accuracy: 0.9524 - val_loss: 0.7864
# Epoch 800/800
# 3/3 - 0s - 33ms/step - accuracy: 1.0000 - loss: 0.4971 - val_accuracy: 0.9524 - val_loss: 0.7925

# %% [markdown]
# #### Plot the learning curves
#
# Let's now plot the loss and accuracy for the training and validation sets.

# %%
#Run this cell to plot the new accuracy vs epoch graph

try:
    plt.plot(reg_history.history['accuracy'])
    plt.plot(reg_history.history['val_accuracy'])
except KeyError:
    plt.plot(reg_history.history['acc'])
    plt.plot(reg_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
#Run this cell to plot the new loss vs epoch graph

plt.plot(reg_history.history['loss'])
plt.plot(reg_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# We can see that the regularisation has helped to reduce the overfitting of the network.
# You will now incorporate callbacks into a new training run that implements early stopping and learning rate reduction on plateaux.
#
# Fill in the function below so that:
#
# * It creates an `EarlyStopping` callback object and a `ReduceLROnPlateau` callback object
# * The early stopping callback is used and monitors validation loss with the mode set to `"min"` and patience of 30.
# * The learning rate reduction on plateaux is used with a learning rate factor of 0.2 and a patience of 20.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure to not change the function name or arguments.

def get_callbacks():
    """
    This function should create and return a tuple (early_stopping, learning_rate_reduction) callbacks.
    The callbacks should be instantiated according to the above requirements.
    """

    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        mode="min",
        patience=30,
        restore_best_weights=True
    )

    learning_rate_reduction = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.2,
        patience=20
    )

    return early_stopping, learning_rate_reduction

# %% [markdown]
# Run the cell below to instantiate and train the regularised model with the callbacks.

# %%
call_model = get_regularised_model(train_data[0].shape, 0.3, 0.0001)
compile_model(call_model)
early_stopping, learning_rate_reduction = get_callbacks()
call_history = call_model.fit(train_data, train_targets, epochs=800, validation_split=0.15,
                         callbacks=[early_stopping, learning_rate_reduction], verbose=0)
# Out:
# 2025-11-26 23:53:29.215923: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:29.215989: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:29.215998: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:29.216056: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:29.216062: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:29.216084: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:29.216089: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:29.216099: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:30.335314: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1094', 36 bytes spill stores, 36 bytes spill loads
#
# 2025-11-26 23:53:30.375975: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_615', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-26 23:53:30.574005: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_615', 100 bytes spill stores, 100 bytes spill loads
#
# 2025-11-26 23:53:31.895252: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1936', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 23:53:32.085541: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1960', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-11-26 23:53:32.705899: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1230', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-11-26 23:53:33.133556: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1936', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-26 23:53:33.348894: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1936', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-11-26 23:53:33.656677: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1953', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-11-26 23:53:38.273585: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:38.273694: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:38.273706: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:38.273770: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:38.273786: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-26 23:53:39.304485: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_615', 292 bytes spill stores, 292 bytes spill loads
#
# 2025-11-26 23:53:39.414171: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1230', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-26 23:53:39.513987: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1094', 36 bytes spill stores, 36 bytes spill loads
#
# 2025-11-26 23:53:39.585282: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1094', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-26 23:53:40.106673: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_615', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-11-26 23:53:40.454499: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1230', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-11-26 23:53:41.191341: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1600', 16 bytes spill stores, 16 bytes spill loads

# %%
learning_rate_reduction.patience
# Out:
# 20

# %% [markdown]
# Finally, let's replot the accuracy and loss graphs for our new model.

# %%
try:
    plt.plot(call_history.history['accuracy'])
    plt.plot(call_history.history['val_accuracy'])
except KeyError:
    plt.plot(call_history.history['acc'])
    plt.plot(call_history.history['val_acc'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(call_history.history['loss'])
plt.plot(call_history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Evaluate the model on the test set

test_loss, test_acc = call_model.evaluate(test_data, test_targets, verbose=0)
print("Test loss: {:.3f}\nTest accuracy: {:.2f}%".format(test_loss, 100 * test_acc))
# Out:
# Test loss: 0.149
# Test accuracy: 93.33%

# %% [markdown]
# Congratulations for completing this programming assignment! In the next week of the course we will learn how to save and load pre-trained models.
