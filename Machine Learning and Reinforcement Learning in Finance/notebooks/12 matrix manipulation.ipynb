# %% [markdown]
# Muy bien. Lo que necesitas es una especie de “mapa mental” de qué se puede hacer con matrices, qué **sí es igual** a los números, qué **cambia**, y qué operaciones nuevas aparecen.
#
# ---
#
# # 🔹 Tabla de analogías: escalares vs. matrices
#
# | Escalares ($\mathbb{R}$)   | Matrices ($\mathbb{R}^{n\times n}$) | Comentarios                                          |
# | -------------------------- | ----------------------------------- | ---------------------------------------------------- |
# | $a+b=b+a$                  | $A+B=B+A$                           | **Conmutativo** en la suma.                          |           |                                                                |
# | $ab=ba$                    | $AB \neq BA$ en general             | **No conmutativo** en producto.                      |           |                                                                |
# | $a^{-1}=1/a$               | $A^{-1}$ tal que $AA^{-1}=I$        | Existe solo si $A$ es invertible.                    |           |                                                                |
# | $a^k$ (potencia)           | $A^k=A\cdot A\cdots A$              | Bien definido para enteros positivos.                |           |                                                                |
# | $\sqrt{a}$                 | $B$ tal que $B^2=A$                 | Solo para matrices especiales (simétricas p.s.d.).   |           |                                                                |
# | $e^a=\sum \tfrac{a^k}{k!}$ | $e^A=\sum \tfrac{A^k}{k!}$          | Se usa en sistemas dinámicos ($x'(t)=Ax$).           |           |                                                                |
# | $\ln a$                    | $\ln A$                             | Requiere que $A$ sea invertible y bien condicionado. |           |                                                                |
# | (                          a                                   )                                                    | $\det(A)$ | El determinante mide “escala de volumen” de la transformación. |
# | signo de $a$               | $\text{tr}(A)$                      | La traza resume “suma de autovalores”.               |           |                                                                |
#
# ---
#
# # 🔹 Propiedades fundamentales de matrices
#
# 1. **Simetría**
#    Una matriz simétrica $A=A^\top$ tiene autovalores reales y autovectores ortogonales.
#    → Fundamental en estadística: matrices de covarianza son siempre simétricas p.s.d.
#
# 2. **Definida positiva**
#    $A$ es positiva definida si
#
#    $$
#    x^\top A x > 0 \quad \forall x\neq 0.
#    $$
#
#    → Interpretable como “todas las direcciones tienen varianza positiva”.
#
# 3. **Determinante**
#    $\det(A)$: cuánto escala los volúmenes la transformación lineal asociada.
#    Si $\det(A)=0$, la matriz colapsa el espacio (no es invertible).
#
# 4. **Traza**
#    $\mathrm{tr}(A)=\sum_i a_{ii} = \sum \lambda_i$ (suma de autovalores).
#    Muy útil: $\mathrm{tr}(AB)=\mathrm{tr}(BA)$.
#
# 5. **Autovalores y autovectores**
#    Resolviendo $Av=\lambda v$.
#    → Son las “direcciones propias” de la transformación, con “escalas propias” $\lambda$.
#    Ejemplo: PCA diagonaliza la covarianza usando esto.
#
# 6. **Ortogonalidad**
#    Si $Q^\top Q=I$, la matriz $Q$ preserva longitudes y ángulos (rotaciones/reflejos).
#
# ---
#
# # 🔹 Cálculo matricial
#
# * **Integración**:
#
#   $$
#   \int f(t)\,dt \quad\to\quad \int M(t)\,dt
#   $$
#
#   se hace entrada a entrada.
#
# * **Derivadas**:
#   Ejemplo: si $f(x)=x^\top Ax$ con $A$ simétrica, entonces
#   $\nabla f(x) = 2Ax$.
#
# * **Series**:
#   Cualquier serie de potencias que funciona para escalares también funciona para matrices, siempre que converja:
#
#   $$
#   \cos(A), \; \sin(A), \; e^A, \; (I-A)^{-1}=\sum_{k=0}^\infty A^k \;\; \text{si }\|A\|<1.
#   $$
#
# ---
#
# # 🔹 Cosas nuevas que no existen en escalares
#
# * **Dimensión**: las matrices pueden tener rangos menores → colapsan dimensiones.
# * **Normas matriciales**: $\|A\|$ mide la magnitud como operador.
# * **Pseudoinversa**: incluso si $A$ no es invertible, se puede usar la inversa de Moore–Penrose.
# * **Descomposiciones**:
#
#   * **LU**: $A=LU$.
#   * **QR**: $A=QR$.
#   * **SVD**: $A=U\Sigma V^\top$.
#   * **Espectral**: $A=Q\Lambda Q^\top$ si $A$ es simétrica.
#
# ---
#
# 👉 **Resumen:** las matrices se parecen a los números pero con más “geometría” incorporada. Te dejan rotar, escalar, reflejar y combinar dimensiones. Y sí: puedes derivarlas, integrarlas, exponenciarlas, sacarlas raíz, pero bajo condiciones.
#
# ¿Quieres que arme una **guía de ejercicios graduados** solo de manipulación de matrices con estas propiedades (determinante, traza, inversa, exp, raíz, etc.)?
